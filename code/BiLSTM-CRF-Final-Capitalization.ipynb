# %% [markdown]
# # CSE 291 Assignment 2 BiLSTM CRF

# %% [markdown]
# ## Download Data/Eval Script

# %%
# !wget https://raw.githubusercontent.com/sighsmile/conlleval/master/conlleval.py
# !wget https://raw.githubusercontent.com/tberg12/cse291spr21/main/assignment2/train.data.quad
# !wget https://raw.githubusercontent.com/tberg12/cse291spr21/main/assignment2/dev.data.quad

# %%
import conlleval
from tqdm import tqdm
import numpy as np
from collections import defaultdict, Counter
import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.optim as optim
from torchtext.vocab import Vocab
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
import pdb 
from sklearn.metrics import precision_recall_fscore_support


torch.manual_seed(291)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# ## Data Preparation

# %%
TRAIN_DATA = 'train.data.quad'
VALID_DATA = 'dev.data.quad'
UNK = '<unk>'
PAD = '<pad>'
START_TAG = "<start>"  # you can add this explicitly or use it implicitly in your CRF layer
STOP_TAG = "<stop>"    # you can add this explicitly or use it implicitly in your CRF layer


def read_conll_sentence(path):
    """ Read a CONLL-format sentence into vocab objects
    Args:
        :param path: path to CONLL-format data file
        :param word_vocab: Vocabulary object for source
        :param label_vocab: Vocabulary object for target
    """
    sent = [[], []]
    with open(path) as f:
        for line in f:
            line = line.strip().split()
            if line:
                # replace numbers with 0000
                word = line[0]
                word = '0000' if word.isnumeric() else word
                sent[0].append(word)
                sent[1].append(line[3])
            else:
                yield sent[0], sent[1]
                sent = [[], []]



def prepare_dataset(dataset, word_vocab, label_vocab):
    dataset = [
      [
        torch.tensor([word_vocab.stoi[word] for word in sent[0]], dtype=torch.long),
        torch.tensor([label_vocab.stoi[label] for label in sent[1]], dtype=torch.long),
      ]
      for sent in dataset
    ]
    return dataset


# load a list of sentences, where each word in the list is a tuple containing the word and the label
train_data = list(read_conll_sentence(TRAIN_DATA))
train_word_counter = Counter([word for sent in train_data for word in sent[0]])
train_label_counter = Counter([label for sent in train_data for label in sent[1]])
word_vocab = Vocab(train_word_counter, specials=(UNK, PAD), min_freq=2)
label_vocab = Vocab(train_label_counter, specials=(), min_freq=1)
print(train_data[0])

train_raw_sent = [" ".join(sent[0]) for sent in train_data]

train_data = prepare_dataset(train_data, word_vocab, label_vocab)
print('Train word vocab:', len(word_vocab), 'symbols.')
print('Train label vocab:', len(label_vocab), f'symbols: {list(label_vocab.stoi.keys())}')
valid_data = list(read_conll_sentence(VALID_DATA))

val_raw_sent = [" ".join(sent[0]) for sent in valid_data]

valid_data = prepare_dataset(valid_data, word_vocab, label_vocab)
print('Train data:', len(train_data), 'sentences.')
print('Valid data:', len(valid_data))

print(' '.join([word_vocab.itos[i.item()] for i in train_data[1][0]]))
print(' '.join([label_vocab.itos[i.item()] for i in train_data[1][1]]))

print(' '.join([word_vocab.itos[i.item()] for i in valid_data[1][0]]))
print(' '.join([label_vocab.itos[i.item()] for i in valid_data[1][1]]))
# Out:
# (['Pusan', '0000', '0000', '0000', '0000', '0000', '0000'], ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O'])
# Train word vocab: 3947 symbols.
# Train label vocab: 8 symbols: ['O', 'I-PER', 'I-ORG', 'I-LOC', 'I-MISC', 'B-MISC', 'B-ORG', 'B-LOC']
# Train data: 3420 sentences.
# Valid data: 800
# Martin Brooks , president of Miss Universe Inc , said he spoke with Machado to <unk> her that organisers were not <unk> pressure on her .
# I-PER I-PER O O O I-ORG I-ORG I-ORG O O O O O I-PER O O O O O O O O O O O O
# Earlier this month , <unk> denied a Kabul government statement that the two sides had agreed to a ceasefire in the north .
# O O O O I-PER O O I-LOC O O O O O O O O O O O O O O O

# %%
# inVocabWord = set((val_word_vocab.freqs)).intersection(set(word_vocab.freqs))
# oovWord = set((val_word_vocab.freqs)).difference(set(word_vocab.freqs))

# %%
embeddingTrainDict = {}

for i, (sent, tags) in enumerate(train_data):
    sentence = train_raw_sent[i]
    embeddingTrainDict[i] = (torch.Tensor([[1] if word[0].isupper() else [0] for word in train_raw_sent[i].split()])).unsqueeze(0).to(device)

embeddingValDict = {}

for i, (sent, tags) in enumerate(valid_data):
    
    embeddingValDict[i] = (torch.Tensor([[1] if word[0].isupper() else [0] for word in val_raw_sent[i].split()])).unsqueeze(0).to(device)

# %%
embeddingTrainDict[0].shape
# Out:
# torch.Size([1, 7, 1])

# %%
train_raw_sent[0]
# Out:
# 'Pusan 0000 0000 0000 0000 0000 0000'

# %%
def log_sum_exp(vec):
    max_score = vec.max()
    max_score_broadcast = max_score.view(1, -1).expand(1, vec.size()[1])
    return max_score + torch.log(torch.sum(torch.exp(vec - max_score_broadcast)))

# %% [markdown]
# ## BiLSTMTagger

# %%
class CRF():
    def __init__(self, vocab_size, tag_vocab_size):
        
        self.vocab_size = vocab_size
        self.tagset_size = tag_vocab_size

        self.transitions = nn.Parameter(
            torch.randn(self.tagset_size, self.tagset_size)).to(device)

        self.start_index = tag_vocab_size - 2
        self.end_index = tag_vocab_size - 1
        
        self.transitions.data[self.start_index, :] = -10000
        self.transitions.data[:, self.end_index] = -10000
        
    
    def _viterbi_decode(self, feats):
        backtrace = []
        alpha = torch.full((1, self.tagset_size), -10000.0, device=device)
        alpha[0][self.start_index] = 0
        feats = feats.squeeze(0)
#         pdb.set_trace()
        for feat in feats:
            t2 = (self.transitions.T + (feat)).T + alpha
            t3 = t2.max(dim=1).values
            alpha = t3 + (t2.T - t3).T.exp().sum(dim=1).log().view(1,-1)
            backtrace.append(t2.argmax(dim=1))

        vec = alpha.T + self.transitions[:, [self.end_index]]
        
        best_tag = vec.squeeze(1).argmax().item()
        optimal_path = [best_tag]
        
        seq = reversed(backtrace[1:])
        
        for bp in seq: 
            best_tag = bp[best_tag].item()
            optimal_path.append(best_tag)
        
        score = (vec - vec.max()).exp().sum(axis=0, keepdim=True).log() + vec.max()
        return score,[ optimal_path[::-1]] 
    
     
    def _forward_alg(self, feats):
        init_alphas = torch.full((1, self.tagset_size), -10000.)

        init_alphas[0][self.start_index] = 0.


        forward_var = init_alphas.to(device)

        feats = feats.squeeze(0)

        for feat in feats:
            alphas_t = []  # The forward tensors at this timestep
            t2 = (self.transitions.T + (feat)).T + forward_var
            t3 = t2.max(dim=1).values
            forward_var = t3 + (t2.T - t3).T.exp().sum(dim=1).log().view(1,-1)

        terminal_var = forward_var + self.transitions[self.end_index]
        alpha = log_sum_exp(terminal_var)
        return alpha
    
    
    def _score_sentence(self, feats, tags):

        score = torch.zeros(1).to(device)
        feats = feats.squeeze(0)
        tags = tags.squeeze(0)
        tags = torch.cat([torch.tensor([self.start_index], dtype=torch.long).to(device), tags]).to(device)
        for i, feat in enumerate(feats):
            score = score + self.transitions[tags[i + 1], tags[i]] + feat[tags[i + 1]]

        score = score + self.transitions[self.end_index, tags[-1]]
        return score

# %%
# Starter code implementing a BiLSTM Tagger
# which makes locally normalized, independent
# tag classifications at each time step

class BiLSTMTagger(nn.Module):
    def __init__(self, vocab_size, tag_vocab_size, embedding_dim, hidden_dim, dropout=0.3, feature_size=1):
        super(BiLSTMTagger, self).__init__()
        self.embedding_dim = embedding_dim
        self.hidden_dim = hidden_dim
        self.vocab_size = vocab_size
        self.tagset_size = tag_vocab_size
        self.word_embeds = nn.Embedding(vocab_size, embedding_dim).to(device)
        self.bilstm = nn.LSTM(embedding_dim+feature_size, hidden_dim // 2,
                            num_layers=1, bidirectional=True, batch_first=True).to(device)
        self.tag_projection_layer = nn.Linear(hidden_dim, self.tagset_size).to(device)
        self.dropout = nn.Dropout(p=dropout)

        self.crf = CRF(vocab_size, tag_vocab_size)


    def init_hidden(self):
        return (torch.randn(2, 1, self.hidden_dim // 2).to(device),
                torch.randn(2, 1, self.hidden_dim // 2).to(device))

    def compute_lstm_emission_features(self, sentence, feature):
        hidden = self.init_hidden()
        embeds = self.dropout(self.word_embeds(sentence))
        bilstm_out, hidden = self.bilstm(torch.cat((embeds, feature),dim=2), hidden)
        bilstm_out = self.dropout(bilstm_out)
        bilstm_out = bilstm_out
        bilstm_feats = self.tag_projection_layer(bilstm_out)
        return bilstm_feats

    
    def forward(self, sentence, feature):
        bilstm_feats = self.compute_lstm_emission_features(sentence, feature)

        return self.crf._viterbi_decode(bilstm_feats)
    

    def loss(self, sentence, tags, feature):
        feats = self.compute_lstm_emission_features(sentence, feature)
        forward_score = self.crf._forward_alg(feats)
        gold_score = self.crf._score_sentence(feats, tags)
        return forward_score - gold_score

# %% [markdown]
# ## Train / Eval loop

# %%
def train(model, train_data, valid_data, word_vocab, label_vocab, epochs, log_interval=25):
    losses_per_epoch = []
    for epoch in range(epochs):
        print(f'--- EPOCH {epoch} ---')
        model.train()
        losses_per_epoch.append([])
        for i, (sent, tags) in enumerate(train_data):
            model.zero_grad()
            sent, tags = sent.to(device), tags.to(device)
            sent = sent.unsqueeze(0)
            tags = tags.unsqueeze(0)
            loss = model.loss(sent, tags, embeddingTrainDict[i])
            loss.backward()
            optimizer.step()

            losses_per_epoch[-1].append(loss.detach().cpu().item())
            if i > 0 and i % log_interval == 0:
                print(f'Avg loss over last {log_interval} updates: {np.mean(losses_per_epoch[-1][-log_interval:])}')

        evaluate(model, valid_data, word_vocab, label_vocab)


def evaluate(model, dataset, word_vocab, label_vocab):
    model.eval()
    losses = []
    scores = []
    true_tags = []
    pred_tags = []
    sents = []
    for i, (sent, tags) in enumerate(dataset):
        if i == 0:
            pass
        with torch.no_grad():
            sent, tags = sent.to(device), tags.to(device)
            sent = sent.unsqueeze(0)
            tags = tags.unsqueeze(0)
            losses.append(model.loss(sent, tags, embeddingValDict[i]).cpu().detach().item())
            score, pred_tag_seq = model(sent, embeddingValDict[i])
            scores.append(score)
            try:
                true_tags.append([label_vocab.itos[i] for i in tags.tolist()[0]])
                pred_tags.append([ label_vocab.itos[0] if i == 9 else label_vocab.itos[i] for i in pred_tag_seq[0]])
            except:
                print(pred_tag_seq)
                pass

            sents.append([word_vocab.itos[i] for i in sent[0]])

    print('Avg evaluation loss:', np.mean(losses))
    a = [tag for tags in true_tags for tag in tags]
    b = [tag for tags in pred_tags for tag in tags]
    print(conlleval.evaluate(a, b, verbose=True))


    scores_token = precision_recall_fscore_support(a,b, average=None, labels=label_vocab.itos)
    for i in range(len(label_vocab.itos)):
        print(label_vocab.itos[i] , "precision", scores_token[0][i], "recall", scores_token[1][i], "f1", scores_token[2][i], "count", scores_token[3][i])

#     print('\n5 random evaluation samples:')
#     for i in np.random.randint(0, len(sents), size=2):
#         print('SENT:', ' '.join(sents[i]))
#         print('TRUE:', ' '.join(true_tags[i]))
#         print('PRED:', ' '.join(pred_tags[i]))
    return sents, true_tags, pred_tags

# %% [markdown]
# ## Training

# %%
# Train BiLSTM Tagger Baseline
model = BiLSTMTagger(len(word_vocab), len(label_vocab)+2, 128, 256).to(device)


optimizer = optim.Adam(model.parameters(), lr=1e-3)
train(model, train_data, valid_data, word_vocab, label_vocab, epochs=10, log_interval=500)
# Out:
# --- EPOCH 0 ---
# Avg loss over last 500 updates: 10.385956935405732
# Avg loss over last 500 updates: 7.233801934480667
# Avg loss over last 500 updates: 4.807391242742538
# Avg loss over last 500 updates: 4.248341681003571
# Avg loss over last 500 updates: 3.521166482448578
# Avg loss over last 500 updates: 3.534409637928009
# Avg evaluation loss: 3.278457882106304
# processed 11170 tokens with 1231 phrases; found: 1323 phrases; correct: 667.
# accuracy:  60.85%; (non-O)
# accuracy:  92.09%; precision:  50.42%; recall:  54.18%; FB1:  52.23
#               LOC: precision:  72.66%; recall:  51.24%; FB1:  60.10  256
#              MISC: precision:  38.78%; recall:  29.69%; FB1:  33.63  147
#               ORG: precision:  33.20%; recall:  53.09%; FB1:  40.85  491
#               PER: precision:  60.84%; recall:  70.73%; FB1:  65.41  429
# (50.41572184429327, 54.18359057676686, 52.23179326546593)
# O precision 0.9779529236340399 recall 0.9816121445370964 f1 0.9797791175372139 count 9354
# I-PER precision 0.6889495225102319 recall 0.7915360501567398 f1 0.7366885485047411 count 638
# I-ORG precision 0.4620355411954766 recall 0.5836734693877551 f1 0.5157799819657349 count 490
# I-LOC precision 0.8079710144927537 recall 0.530952380952381 f1 0.6408045977011494 count 420
# I-MISC precision 0.5947712418300654 recall 0.34600760456273766 f1 0.4375 count 263
# B-MISC precision 0.0 recall 0.0 f1 0.0 count 1
# B-ORG precision 0.0 recall 0.0 f1 0.0 count 0
# B-LOC precision 0.0 recall 0.0 f1 0.0 count 4
# --- EPOCH 1 ---
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Avg loss over last 500 updates: 3.0160853567123413
# Avg loss over last 500 updates: 3.3547597320079805
# Avg loss over last 500 updates: 2.601821985244751
# Avg loss over last 500 updates: 2.670689762592316
# Avg loss over last 500 updates: 2.082819594860077
# Avg loss over last 500 updates: 2.3880317096710204
# Avg evaluation loss: 2.594623070061207
# processed 11170 tokens with 1231 phrases; found: 1316 phrases; correct: 822.
# accuracy:  70.32%; (non-O)
# accuracy:  93.98%; precision:  62.46%; recall:  66.77%; FB1:  64.55
#               LOC: precision:  80.31%; recall:  70.80%; FB1:  75.26  320
#              MISC: precision:  62.00%; recall:  48.44%; FB1:  54.39  150
#               ORG: precision:  42.86%; recall:  62.54%; FB1:  50.86  448
#               PER: precision:  70.35%; recall:  75.88%; FB1:  73.01  398
# (62.462006079027354, 66.77497969130788, 64.54652532391049)
# O precision 0.9824206264649478 recall 0.9857814838571735 f1 0.9840981856990395 count 9354
# I-PER precision 0.7906626506024096 recall 0.822884012539185 f1 0.8064516129032259 count 638
# I-ORG precision 0.5510887772194305 recall 0.6714285714285714 f1 0.6053357865685373 count 490
# I-LOC precision 0.8356545961002786 recall 0.7142857142857143 f1 0.7702182284980745 count 420
# I-MISC precision 0.75 recall 0.467680608365019 f1 0.576112412177986 count 263
# B-MISC precision 0.0 recall 0.0 f1 0.0 count 1
# B-ORG precision 0.0 recall 0.0 f1 0.0 count 0
# B-LOC precision 0.0 recall 0.0 f1 0.0 count 4
# --- EPOCH 2 ---
# Avg loss over last 500 updates: 2.1305329093933105
# Avg loss over last 500 updates: 2.4262135252952577
# Avg loss over last 500 updates: 1.834173921108246
# Avg loss over last 500 updates: 2.0603632011413575
# Avg loss over last 500 updates: 1.6592591962814331
# Avg loss over last 500 updates: 1.8289232280254364
# Avg evaluation loss: 2.3266765853762625
# processed 11170 tokens with 1231 phrases; found: 1263 phrases; correct: 857.
# accuracy:  73.73%; (non-O)
# accuracy:  94.83%; precision:  67.85%; recall:  69.62%; FB1:  68.72
#               LOC: precision:  79.65%; recall:  74.38%; FB1:  76.92  339
#              MISC: precision:  74.07%; recall:  52.08%; FB1:  61.16  135
#               ORG: precision:  49.76%; recall:  66.45%; FB1:  56.90  410
#               PER: precision:  74.67%; recall:  76.69%; FB1:  75.67  379
# (67.85431512272368, 69.61819658813972, 68.72493985565356)
# O precision 0.9836309523809523 recall 0.989309386358777 f1 0.9864619976548342 count 9354
# I-PER precision 0.8265625 recall 0.829153605015674 f1 0.8278560250391236 count 638
# I-ORG precision 0.6188034188034188 recall 0.7387755102040816 f1 0.6734883720930233 count 490
# I-LOC precision 0.8263157894736842 recall 0.7476190476190476 f1 0.785 count 420
# I-MISC precision 0.8535031847133758 recall 0.5095057034220533 f1 0.6380952380952383 count 263
# B-MISC precision 0.0 recall 0.0 f1 0.0 count 1
# B-ORG precision 0.0 recall 0.0 f1 0.0 count 0
# B-LOC precision 0.0 recall 0.0 f1 0.0 count 4
# --- EPOCH 3 ---
# Avg loss over last 500 updates: 1.5735661425590515
# Avg loss over last 500 updates: 1.932763075351715
# Avg loss over last 500 updates: 1.4827505807876586
# Avg loss over last 500 updates: 1.72120245885849
# Avg loss over last 500 updates: 1.2761058273315429
# Avg loss over last 500 updates: 1.448117296218872
# Avg evaluation loss: 2.249508669525385
# processed 11170 tokens with 1231 phrases; found: 1273 phrases; correct: 890.
# accuracy:  75.83%; (non-O)
# accuracy:  95.18%; precision:  69.91%; recall:  72.30%; FB1:  71.09
#               LOC: precision:  84.80%; recall:  76.86%; FB1:  80.64  329
#              MISC: precision:  65.87%; recall:  57.29%; FB1:  61.28  167
#               ORG: precision:  53.54%; recall:  66.45%; FB1:  59.30  381
#               PER: precision:  75.00%; recall:  80.49%; FB1:  77.65  396
# (69.91358994501178, 72.29894394800975, 71.08626198083067)
# O precision 0.9843650287172941 recall 0.9894162924951893 f1 0.9868841970569417 count 9354
# I-PER precision 0.8273273273273273 recall 0.8636363636363636 f1 0.8450920245398773 count 638
# I-ORG precision 0.6629213483146067 recall 0.7224489795918367 f1 0.69140625 count 490
# I-LOC precision 0.8659517426273459 recall 0.7690476190476191 f1 0.8146279949558638 count 420
# I-MISC precision 0.764102564102564 recall 0.5665399239543726 f1 0.650655021834061 count 263
# B-MISC precision 0.0 recall 0.0 f1 0.0 count 1
# B-ORG precision 0.0 recall 0.0 f1 0.0 count 0
# B-LOC precision 0.0 recall 0.0 f1 0.0 count 4
# --- EPOCH 4 ---
# Avg loss over last 500 updates: 1.2755050854682923
# Avg loss over last 500 updates: 1.5562570486068725
# Avg loss over last 500 updates: 1.1666484920978546
# Avg loss over last 500 updates: 1.414741037130356
# Avg loss over last 500 updates: 1.0110315597057342
# Avg loss over last 500 updates: 1.2831580004692078
# Avg evaluation loss: 2.1864896376430987
# processed 11170 tokens with 1231 phrases; found: 1288 phrases; correct: 904.
# accuracy:  77.20%; (non-O)
# accuracy:  95.22%; precision:  70.19%; recall:  73.44%; FB1:  71.77
#               LOC: precision:  87.69%; recall:  78.51%; FB1:  82.85  325
#              MISC: precision:  71.17%; recall:  60.42%; FB1:  65.35  163
#               ORG: precision:  51.09%; recall:  68.73%; FB1:  58.61  413
#               PER: precision:  75.45%; recall:  79.13%; FB1:  77.25  387
# (70.1863354037267, 73.43623070674249, 71.77451369591108)
# O precision 0.9862223646267222 recall 0.9871712636305324 f1 0.9866965859913448 count 9354
# I-PER precision 0.8262195121951219 recall 0.8495297805642633 f1 0.8377125193199382 count 638
# I-ORG precision 0.6317567567567568 recall 0.763265306122449 f1 0.6913123844731979 count 490
# I-LOC precision 0.896457765667575 recall 0.7833333333333333 f1 0.8360864040660737 count 420
# I-MISC precision 0.8177083333333334 recall 0.596958174904943 f1 0.6901098901098902 count 263
# B-MISC precision 0.0 recall 0.0 f1 0.0 count 1
# B-ORG precision 0.0 recall 0.0 f1 0.0 count 0
# B-LOC precision 0.0 recall 0.0 f1 0.0 count 4
# --- EPOCH 5 ---
# Avg loss over last 500 updates: 1.0859731097221375
# Avg loss over last 500 updates: 1.248094913482666
# Avg loss over last 500 updates: 0.9980025849342347
# Avg loss over last 500 updates: 1.2131383953094483
# Avg loss over last 500 updates: 0.8726981739997863
# Avg loss over last 500 updates: 1.0578606023788453
# Avg evaluation loss: 2.2617223396897317
# processed 11170 tokens with 1231 phrases; found: 1280 phrases; correct: 920.
# accuracy:  77.53%; (non-O)
# accuracy:  95.40%; precision:  71.88%; recall:  74.74%; FB1:  73.28
#               LOC: precision:  83.72%; recall:  79.34%; FB1:  81.47  344
#              MISC: precision:  63.73%; recall:  64.06%; FB1:  63.90  193
#               ORG: precision:  57.83%; recall:  66.12%; FB1:  61.70  351
#               PER: precision:  78.06%; recall:  82.93%; FB1:  80.42  392
# (71.875, 74.73598700243704, 73.27757865392273)
# O precision 0.9851922872057101 recall 0.9886679495403036 f1 0.9869270583213275 count 9354
# I-PER precision 0.843939393939394 recall 0.8730407523510971 f1 0.8582434514637903 count 638
# I-ORG precision 0.6936758893280632 recall 0.7163265306122449 f1 0.7048192771084336 count 490
# I-LOC precision 0.8634020618556701 recall 0.7976190476190477 f1 0.8292079207920793 count 420
# I-MISC precision 0.7205240174672489 recall 0.6273764258555133 f1 0.6707317073170732 count 263
# B-MISC precision 0.0 recall 0.0 f1 0.0 count 1
# B-ORG precision 0.0 recall 0.0 f1 0.0 count 0
# B-LOC precision 0.0 recall 0.0 f1 0.0 count 4
# --- EPOCH 6 ---
# Avg loss over last 500 updates: 0.9297854328155517
# Avg loss over last 500 updates: 1.0836975865364076
# Avg loss over last 500 updates: 0.9718671810626983
# Avg loss over last 500 updates: 0.991996078491211
# Avg loss over last 500 updates: 0.8088138036727905
# Avg loss over last 500 updates: 1.0028251304626465
# Avg evaluation loss: 2.3647192503511905
# processed 11170 tokens with 1231 phrases; found: 1265 phrases; correct: 920.
# accuracy:  78.52%; (non-O)
# accuracy:  95.60%; precision:  72.73%; recall:  74.74%; FB1:  73.72
#               LOC: precision:  84.23%; recall:  77.96%; FB1:  80.97  336
#              MISC: precision:  70.52%; recall:  63.54%; FB1:  66.85  173
#               ORG: precision:  59.15%; recall:  68.40%; FB1:  63.44  355
#               PER: precision:  76.06%; recall:  82.66%; FB1:  79.22  401
# (72.72727272727273, 74.73598700243704, 73.71794871794872)
# O precision 0.9842553191489362 recall 0.9890955740859525 f1 0.9866695105044258 count 9354
# I-PER precision 0.833578792341679 recall 0.8871473354231975 f1 0.8595292331055429 count 638
# I-ORG precision 0.7222222222222222 recall 0.7428571428571429 f1 0.732394366197183 count 490
# I-LOC precision 0.8753315649867374 recall 0.7857142857142857 f1 0.8281053952321205 count 420
# I-MISC precision 0.7942583732057417 recall 0.6311787072243346 f1 0.7033898305084746 count 263
# B-MISC precision 0.0 recall 0.0 f1 0.0 count 1
# B-ORG precision 0.0 recall 0.0 f1 0.0 count 0
# B-LOC precision 0.0 recall 0.0 f1 0.0 count 4
# --- EPOCH 7 ---
# Avg loss over last 500 updates: 0.7774380660057068
# Avg loss over last 500 updates: 0.9432501759529114
# Avg loss over last 500 updates: 0.8693035645484924
# Avg loss over last 500 updates: 1.0030249650478362
# Avg loss over last 500 updates: 0.6875946764945984
# Avg loss over last 500 updates: 0.8150855383872986
# Avg evaluation loss: 2.2785285487771034
# processed 11170 tokens with 1231 phrases; found: 1253 phrases; correct: 922.
# accuracy:  77.97%; (non-O)
# accuracy:  95.58%; precision:  73.58%; recall:  74.90%; FB1:  74.24
#               LOC: precision:  81.34%; recall:  80.44%; FB1:  80.89  359
#              MISC: precision:  68.64%; recall:  60.42%; FB1:  64.27  169
#               ORG: precision:  60.71%; recall:  66.45%; FB1:  63.45  336
#               PER: precision:  79.69%; recall:  84.01%; FB1:  81.79  389
# (73.58339984038308, 74.89845653939886, 74.23510466988729)
# O precision 0.9839549463393901 recall 0.9899508231772504 f1 0.9869437783106847 count 9354
# I-PER precision 0.8508371385083714 recall 0.8761755485893417 f1 0.8633204633204633 count 638
# I-ORG precision 0.7278350515463917 recall 0.7204081632653061 f1 0.724102564102564 count 490
# I-LOC precision 0.837772397094431 recall 0.8238095238095238 f1 0.8307322929171669 count 420
# I-MISC precision 0.7745098039215687 recall 0.6007604562737643 f1 0.676659528907923 count 263
# B-MISC precision 0.0 recall 0.0 f1 0.0 count 1
# B-ORG precision 0.0 recall 0.0 f1 0.0 count 0
# B-LOC precision 0.0 recall 0.0 f1 0.0 count 4
# --- EPOCH 8 ---
# Avg loss over last 500 updates: 0.7358342714309692
# Avg loss over last 500 updates: 0.793441381931305
# Avg loss over last 500 updates: 0.7581113562583923
# Avg loss over last 500 updates: 0.8898882803916931
# Avg loss over last 500 updates: 0.575888001203537
# Avg loss over last 500 updates: 0.7575395407676697
# Avg evaluation loss: 2.4458758255839346
# processed 11170 tokens with 1231 phrases; found: 1278 phrases; correct: 934.
# accuracy:  79.24%; (non-O)
# accuracy:  95.60%; precision:  73.08%; recall:  75.87%; FB1:  74.45
#               LOC: precision:  81.10%; recall:  81.54%; FB1:  81.32  365
#              MISC: precision:  73.42%; recall:  60.42%; FB1:  66.29  158
#               ORG: precision:  61.61%; recall:  64.82%; FB1:  63.17  323
#               PER: precision:  74.77%; recall:  87.53%; FB1:  80.65  432
# (73.0829420970266, 75.87327376116978, 74.45197289756875)
# O precision 0.9855984638361425 recall 0.9877057943125935 f1 0.9866510038445109 count 9354
# I-PER precision 0.8099861303744799 recall 0.9153605015673981 f1 0.8594554819720382 count 638
# I-ORG precision 0.7468085106382979 recall 0.7163265306122449 f1 0.7312500000000001 count 490
# I-LOC precision 0.837378640776699 recall 0.8214285714285714 f1 0.829326923076923 count 420
# I-MISC precision 0.8238341968911918 recall 0.6045627376425855 f1 0.6973684210526315 count 263
# B-MISC precision 0.0 recall 0.0 f1 0.0 count 1
# B-ORG precision 0.0 recall 0.0 f1 0.0 count 0
# B-LOC precision 0.0 recall 0.0 f1 0.0 count 4
# --- EPOCH 9 ---
# Avg loss over last 500 updates: 0.6878828706741333
# Avg loss over last 500 updates: 0.7685361938476563
# Avg loss over last 500 updates: 0.7565044865608216
# Avg loss over last 500 updates: 0.7901002078056335
# Avg loss over last 500 updates: 0.5209700570106507
# Avg loss over last 500 updates: 0.6833929061889649
# Avg evaluation loss: 2.485498461723328
# processed 11170 tokens with 1231 phrases; found: 1275 phrases; correct: 940.
# accuracy:  79.74%; (non-O)
# accuracy:  95.73%; precision:  73.73%; recall:  76.36%; FB1:  75.02
#               LOC: precision:  83.90%; recall:  81.82%; FB1:  82.85  354
#              MISC: precision:  73.58%; recall:  60.94%; FB1:  66.67  159
#               ORG: precision:  58.71%; recall:  68.08%; FB1:  63.05  356
#               PER: precision:  78.08%; recall:  85.91%; FB1:  81.81  406
# (73.72549019607844, 76.36068237205524, 75.01995211492418)
# O precision 0.9864489970123773 recall 0.9883472311310669 f1 0.9873972017515754 count 9354
# I-PER precision 0.8435672514619883 recall 0.9043887147335423 f1 0.8729198184568835 count 638
# I-ORG precision 0.7073643410852714 recall 0.7448979591836735 f1 0.7256461232604374 count 490
# I-LOC precision 0.865 recall 0.8238095238095238 f1 0.8439024390243902 count 420
# I-MISC precision 0.8080808080808081 recall 0.6083650190114068 f1 0.6941431670281996 count 263
# B-MISC precision 0.0 recall 0.0 f1 0.0 count 1
# B-ORG precision 0.0 recall 0.0 f1 0.0 count 0
# B-LOC precision 0.0 recall 0.0 f1 0.0 count 4

# %%
label_vocab.__dict__
# Out:
# {'freqs': Counter({'I-ORG': 2258,
#           'O': 38899,
#           'I-PER': 2544,
#           'I-LOC': 1836,
#           'I-MISC': 1011,
#           'B-MISC': 9,
#           'B-ORG': 5,
#           'B-LOC': 3}),
#  'itos': ['O',
#   'I-PER',
#   'I-ORG',
#   'I-LOC',
#   'I-MISC',
#   'B-MISC',
#   'B-ORG',
#   'B-LOC'],
#  'unk_index': None,
#  'stoi': defaultdict(None,
#              {'O': 0,
#               'I-PER': 1,
#               'I-ORG': 2,
#               'I-LOC': 3,
#               'I-MISC': 4,
#               'B-MISC': 5,
#               'B-ORG': 6,
#               'B-LOC': 7}),
#  'vectors': None}

# %%
sents, true_tags, pred_tags =  evaluate(model, valid_data, word_vocab, label_vocab)
# Out:
# Avg evaluation loss: 2.505929661244154
# processed 11170 tokens with 1231 phrases; found: 1279 phrases; correct: 940.
# accuracy:  79.79%; (non-O)
# accuracy:  95.84%; precision:  73.49%; recall:  76.36%; FB1:  74.90
#               LOC: precision:  82.58%; recall:  80.99%; FB1:  81.78  356
#              MISC: precision:  75.16%; recall:  61.46%; FB1:  67.62  157
#               ORG: precision:  60.11%; recall:  68.73%; FB1:  64.13  351
#               PER: precision:  76.39%; recall:  85.91%; FB1:  80.87  415
# (73.49491790461298, 76.36068237205524, 74.9003984063745)
# O precision 0.9868855954792621 recall 0.9895231986316014 f1 0.9882026370575989 count 9354
# I-PER precision 0.8369723435225619 recall 0.9012539184952978 f1 0.8679245283018868 count 638
# I-ORG precision 0.7272727272727273 recall 0.7510204081632653 f1 0.7389558232931728 count 490
# I-LOC precision 0.8653366583541147 recall 0.8261904761904761 f1 0.8453105968331303 count 420
# I-MISC precision 0.8112244897959183 recall 0.6045627376425855 f1 0.6928104575163397 count 263
# B-MISC precision 0.0 recall 0.0 f1 0.0 count 1
# B-ORG precision 0.0 recall 0.0 f1 0.0 count 0
# B-LOC precision 0.0 recall 0.0 f1 0.0 count 4

# %%
a = []
b = []
for i,sent in enumerate(sents):
    for j,word in enumerate(sent):
        if word == "<unk>":
            a.append(true_tags[i][j])
            b.append(pred_tags[i][j])

# %%
scores_token = precision_recall_fscore_support(a,b, average=None, labels=label_vocab.itos)

# %%
scores_token = precision_recall_fscore_support(a,b, average=None, labels=label_vocab.itos)

for i in range(len(label_vocab.itos)):
    print(label_vocab.itos[i] , "precision", round(scores_token[0][i] * 100,2), 
          "recall", round(scores_token[1][i] * 100, 2), "f1", round(scores_token[2][i] * 100, 2), "count", scores_token[3][i])
# Out:
# O precision 94.71 recall 93.85 f1 94.28 count 1431
# I-PER precision 80.16 recall 88.2 f1 83.99 count 449
# I-ORG precision 58.62 recall 69.96 f1 63.79 count 243
# I-LOC precision 65.0 recall 51.49 f1 57.46 count 101
# I-MISC precision 53.85 recall 22.83 f1 32.06 count 92
# B-MISC precision 0.0 recall 0.0 f1 0.0 count 1
# B-ORG precision 0.0 recall 0.0 f1 0.0 count 0
# B-LOC precision 0.0 recall 0.0 f1 0.0 count 4

# %%
sents, true_tags, pred_tags = evaluate(model, valid_data, word_vocab, label_vocab )
# Out:
# Avg evaluation loss: 2.5649742801487445
# processed 11170 tokens with 1231 phrases; found: 1284 phrases; correct: 940.
# accuracy:  79.57%; (non-O)
# accuracy:  95.68%; precision:  73.21%; recall:  76.36%; FB1:  74.75
#               LOC: precision:  83.90%; recall:  81.82%; FB1:  82.85  354
#              MISC: precision:  74.38%; recall:  61.98%; FB1:  67.61  160
#               ORG: precision:  57.85%; recall:  68.40%; FB1:  62.69  363
#               PER: precision:  77.15%; recall:  85.09%; FB1:  80.93  407
# (73.20872274143302, 76.36068237205524, 74.75149105367794)
# O precision 0.9870767916266154 recall 0.9880265127218303 f1 0.9875514238392905 count 9354
# I-PER precision 0.8404726735598228 recall 0.8918495297805643 f1 0.8653992395437263 count 638
# I-ORG precision 0.699047619047619 recall 0.7489795918367347 f1 0.7231527093596058 count 490
# I-LOC precision 0.8592592592592593 recall 0.8285714285714286 f1 0.8436363636363636 count 420
# I-MISC precision 0.805 recall 0.6121673003802282 f1 0.6954643628509719 count 263
# B-MISC precision 0.0 recall 0.0 f1 0.0 count 1
# B-ORG precision 0.0 recall 0.0 f1 0.0 count 0
# B-LOC precision 0.0 recall 0.0 f1 0.0 count 4

# %%
for i in range(len(sents)):
    print(" ".join(sents[i]))
    print(true_tags[i])
    print(pred_tags[i])
    print("\n\n")
# Out:
# -DOCSTART-
# ['O']
# ['O']
#
#
#
# Earlier this month , <unk> denied a Kabul government statement that the two sides had agreed to a ceasefire in the north .
# ['O', 'O', 'O', 'O', 'I-PER', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'I-PER', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# 0000 <unk> <unk> 0000 0000 0000 0000
# ['O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O']
# ['O', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O']
#
#
#
# 9. <unk> <unk> ( China ) <unk>
# ['O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O']
# ['O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O']
#
#
#
# <unk> 0000 0000 0000 0000 0000 0000 0000
# ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# The court <unk> <unk> 's <unk> that <unk> 's <unk> from Denmark , where he was arrested in March last year at the request of German authorities , was illegal .
# ['O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> Sudan plane expected at London 's Stansted .
# ['O', 'I-LOC', 'O', 'O', 'O', 'I-LOC', 'O', 'I-LOC', 'O']
# ['I-MISC', 'I-LOC', 'O', 'O', 'O', 'I-LOC', 'O', 'I-LOC', 'O']
#
#
#
# The town 's <unk> <unk> ground is <unk> only by two <unk> <unk> .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> <unk> <unk> <unk>
# ['O', 'O', 'O', 'I-MISC']
# ['O', 'O', 'O', 'O']
#
#
#
# for , against , points ) :
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# When we <unk> the shares we <unk> ...
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# -DOCSTART-
# ['O']
# ['O']
#
#
#
# Martinez <unk> play against <unk> <unk> of Romania .
# ['I-PER', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O']
# ['I-PER', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O']
#
#
#
# <unk> <unk> 0000 0000 0000 0000 0000 0000 0000
# ['I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# The <unk> said the problem was <unk> during the past month during which time <unk> <unk> 's production has <unk> from maximum <unk> of <unk> bpd to as low as <unk> bpd , <unk> on the crude being run .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> to the <unk> 's weakness , another dealer said banks who might have sold <unk> in Monday 's trading appeared to <unk> away from the market .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# There was no independent confirmation of the report which the spokesman said came from the organisation 's members in Arbil .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O']
#
#
#
# <unk> 1996-08-29
# ['I-LOC', 'O']
# ['I-LOC', 'O']
#
#
#
# Pires scored first with a <unk> shot in the 35th minute before <unk> again from close range just before the break .
# ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> 0000 ( <unk> <unk> , <unk> <unk> , <unk> 69th ) Freiburg 0000 .
# ['I-LOC', 'O', 'O', 'I-PER', 'O', 'O', 'I-PER', 'O', 'O', 'I-ORG', 'O', 'O', 'I-LOC', 'O', 'O']
# ['I-ORG', 'O', 'O', 'I-PER', 'O', 'O', 'I-PER', 'O', 'O', 'I-PER', 'O', 'O', 'I-ORG', 'O', 'O']
#
#
#
# <unk> , whose only win came at the 0000 Texas Open and whose best finish this year was a <unk> tie at the <unk> Open in January , <unk> the <unk> fourth <unk> and added five <unk> to <unk> <unk> <unk> of second place .
# ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> <unk> ( Czech Republic ) beat <unk> <unk> ( Japan ) 6- 0000 3-6 7-5
# ['I-PER', 'I-PER', 'O', 'I-LOC', 'I-LOC', 'O', 'O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O']
# ['I-PER', 'I-PER', 'O', 'I-LOC', 'I-LOC', 'O', 'O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> <unk> <unk> 5,000 Japan
# ['I-MISC', 'O', 'O', 'O', 'I-LOC']
# ['I-MISC', 'O', 'O', 'O', 'I-LOC']
#
#
#
# <unk> <unk> 0000 0000 0000 0000 0000 0000 0000
# ['I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> <unk> ( Belarus ) beat <unk> <unk> ( Spain ) 0000
# ['I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O']
# ['I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O']
#
#
#
# <unk> <unk> <unk> <unk> 1-0 despite <unk> the match with only nine men following the <unk> of <unk> <unk> <unk> and <unk> van der <unk> .
# ['I-ORG', 'I-ORG', 'O', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O']
#
#
#
# At least 0000 miners have been killed in labour <unk> -- sparked by ethnic <unk> -- at <unk> <unk> and Gold <unk> ' <unk> Gold Mining Co this month .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O']
#
#
#
# <unk> <unk>
# ['I-ORG', 'I-ORG']
# ['O', 'I-ORG']
#
#
#
# -DOCSTART-
# ['O']
# ['O']
#
#
#
# -DOCSTART-
# ['O']
# ['O']
#
#
#
# <unk> 0000
# ['I-ORG', 'I-ORG']
# ['I-ORG', 'O']
#
#
#
# " <unk> seen <unk> <unk> his goals ...
# ['O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'O']
#
#
#
# One of the great <unk> who <unk> over a period of English <unk> in Europe in politics and the <unk> .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# Sao Paulo 0000 Santos 0000
# ['I-ORG', 'I-ORG', 'O', 'I-ORG', 'O']
# ['I-ORG', 'I-ORG', 'O', 'I-ORG', 'O']
#
#
#
# -DOCSTART-
# ['O']
# ['O']
#
#
#
# Results of <unk> in the
# ['O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> 0000 0000 0000 0000 0000 0000 0000
# ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> <unk> pitched a <unk> ninth , <unk> out two .
# ['I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> Austria <unk>
# ['O', 'I-LOC', 'O']
# ['O', 'I-LOC', 'O']
#
#
#
# <unk> had been working for the <unk> which provides food to civilians for only a few weeks before he was <unk> .
# ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> - <unk> Williams 0000 , <unk> <unk> 0000 , Juan <unk> 0000
# ['I-ORG', 'O', 'I-PER', 'I-PER', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'I-PER', 'I-PER', 'O']
# ['I-ORG', 'O', 'I-PER', 'I-PER', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'I-PER', 'I-PER', 'O']
#
#
#
# Last year , Martinez , who finished 0000 <unk> second in the world , reached the <unk> before <unk> out to Monica Seles .
# ['O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O']
# ['O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O']
#
#
#
# May 0000 v Durham
# ['O', 'O', 'O', 'I-ORG']
# ['O', 'O', 'O', 'I-ORG']
#
#
#
# <unk> league matches on Sunday :
# ['O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# Poland 's Foreign Minister <unk> Rosati will visit Yugoslavia on September 0000 and 0000 to revive a <unk> between the two governments which was <unk> <unk> in 0000 , <unk> news agency reported on Friday .
# ['I-LOC', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-LOC', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# Reuters has not verified these stories and does not vouch for their accuracy .
# ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# NEW YORK 0000 0000 <unk> 0000
# ['I-ORG', 'I-ORG', 'O', 'O', 'O', 'O']
# ['I-ORG', 'I-ORG', 'O', 'O', 'O', 'O']
#
#
#
# Jim Brady then gave a big <unk> to the <unk> .
# ['I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# -DOCSTART-
# ['O']
# ['O']
#
#
#
# India fishermen say forced to carry Tamil refugees .
# ['I-LOC', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'O']
# ['I-LOC', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'O']
#
#
#
# Pakistan , who <unk> next week , are the third team in the <unk> World Series tournament .
# ['I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'I-MISC', 'O', 'O']
# ['I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'I-MISC', 'O', 'O']
#
#
#
# - Pakistan <unk> <unk> tonnes of <unk> <unk> yellow <unk> from <unk> Inc for $ <unk> per tonne , <unk> U.S. Gulf , agents for the <unk> said .
# ['O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'I-LOC', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> match Blewett came to the wicket with the total on 0000 for two and hit three <unk> during an <unk> innings <unk> 0000 minutes .
# ['O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# CRICKET - ENGLAND <unk> <unk> FOR ONE-DAY <unk> .
# ['O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'I-LOC', 'I-PER', 'I-PER', 'O', 'O', 'I-ORG', 'O']
#
#
#
# He walked three and struck out three in winning for the 10th time in his last 0000 <unk> .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# -DOCSTART-
# ['O']
# ['O']
#
#
#
# Extras ( <unk> <unk> <unk> <unk> ) 0000
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> to the <unk> sector fell <unk> percent to <unk> tonnes , while the <unk> sector rose <unk> percent to <unk> tonnes .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# Canada 's <unk> <unk> finished second in his Williams
# ['I-LOC', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'I-ORG']
# ['I-LOC', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'I-LOC']
#
#
#
# FOR <unk> <unk> <unk> <unk>
# ['O', 'I-MISC', 'I-MISC', 'O', 'O']
# ['O', 'I-PER', 'I-PER', 'O', 'O']
#
#
#
# -DOCSTART-
# ['O']
# ['O']
#
#
#
# <unk> 1996-08-26
# ['I-LOC', 'O']
# ['I-LOC', 'O']
#
#
#
# <unk> 0000 0000 0000 0000 0000 0000 0000
# ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# AUG 0000 <unk> 'S <unk> 0000 <unk> 0000 <unk>
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'I-ORG', 'O', 'I-ORG', 'O', 'I-ORG', 'O', 'I-ORG']
#
#
#
# LONDON 1996-08-28
# ['I-LOC', 'O']
# ['I-LOC', 'O']
#
#
#
# <unk> <unk> , deposed leader of the Indonesian Democratic Party ( <unk> ) has <unk> the government for <unk> her as <unk> leader .
# ['I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'O', 'O']
# ['I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'O', 'O']
#
#
#
# Russian and rebel military <unk> finally met in Chechnya on Tuesday for delayed talks aimed at <unk> a ceasefire <unk> last week by President <unk> Yeltsin 's <unk> Alexander Lebed .
# ['I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'I-PER', 'I-PER', 'O']
# ['I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'I-PER', 'I-PER', 'O']
#
#
#
# <unk> of the fire has been <unk> because of the hot , <unk> , <unk> weather in the region , <unk> said .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'O', 'O']
# ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'O', 'O']
#
#
#
# -DOCSTART-
# ['O']
# ['O']
#
#
#
# Attendance : <unk>
# ['O', 'O', 'O']
# ['O', 'O', 'O']
#
#
#
# MILWAUKEE AT CHICAGO
# ['I-ORG', 'O', 'I-LOC']
# ['I-ORG', 'O', 'I-LOC']
#
#
#
# NAC Breda 0000 Sparta Rotterdam 0000
# ['I-ORG', 'I-ORG', 'O', 'I-ORG', 'I-ORG', 'O']
# ['I-ORG', 'I-ORG', 'O', 'I-ORG', 'I-ORG', 'O']
#
#
#
# <unk> Moody not out 0000
# ['I-PER', 'I-PER', 'O', 'O', 'O']
# ['I-PER', 'I-PER', 'O', 'O', 'O']
#
#
#
# 2. <unk> <unk> ( Finland ) <unk> <unk> <unk>
# ['O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'I-MISC', 'I-MISC', 'O']
# ['O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'I-ORG', 'I-ORG', 'O']
#
#
#
# Ricky <unk> led the way with 0000 off 0000 balls with two <unk> and nine <unk> before retiring .
# ['I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# U.S. debt futures end lower , <unk> by Chicago <unk> .
# ['I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'I-ORG', 'O']
# ['I-LOC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'I-ORG', 'O']
#
#
#
# <unk> 0000 0000 0000 0000 0000 0000 0000
# ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# Suu Kyi , who <unk> a campaign for sanctions on <unk> 's government , was under house arrest for six years without being tried before being released in July 0000 .
# ['I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# -- Amsterdam newsroom <unk> 0000 0000 0000 , <unk> <unk> 0000 0000 0000
# ['O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'O', 'O', 'O', 'O']
#
#
#
# <unk> <unk> AT NEW YORK
# ['I-ORG', 'I-ORG', 'O', 'I-LOC', 'I-LOC']
# ['I-ORG', 'I-ORG', 'O', 'I-LOC', 'I-LOC']
#
#
#
# Reading 0000 0000 0000 0000 0000 0000 0000
# ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> from the <unk> at 0000 to 0000 <unk> ( 0000 to 0000 <unk> / 0000 to 0000 miles per hour ) .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# From central Texas north to Kansas , <unk> throughout July and August have <unk> most of the <unk> conditions that <unk> the region earlier this year .
# ['O', 'O', 'I-LOC', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'I-ORG', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# -DOCSTART-
# ['O']
# ['O']
#
#
#
# SOCCER - <unk> FIRST DIVISION SUMMARY .
# ['O', 'O', 'I-MISC', 'O', 'O', 'O', 'O']
# ['O', 'O', 'I-MISC', 'O', 'O', 'O', 'O']
#
#
#
# At Leicester : <unk> drawn .
# ['O', 'I-LOC', 'O', 'O', 'O', 'O']
# ['O', 'I-LOC', 'O', 'I-ORG', 'O', 'O']
#
#
#
# <unk> Bremen 0000 <unk> <unk> 0000
# ['I-ORG', 'I-ORG', 'O', 'I-ORG', 'I-ORG', 'O']
# ['I-ORG', 'I-ORG', 'O', 'I-ORG', 'I-ORG', 'O']
#
#
#
# SOCCER - <unk> <unk> <unk> <unk> <unk> MANCHESTER <unk> .
# ['O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'I-LOC', 'I-LOC', 'O']
# ['O', 'O', 'I-PER', 'O', 'O', 'O', 'I-ORG', 'I-LOC', 'O', 'O']
#
#
#
# <unk> president <unk> Meri won 0000 votes compared to 0000 won by his rival , <unk> <unk> <unk> <unk> Ruutel .
# ['O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O']
# ['O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O']
#
#
#
# 4. El <unk> <unk> ( Morocco ) <unk>
# ['O', 'I-PER', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O']
# ['O', 'I-PER', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O']
#
#
#
# <unk> 0000 0000 0000 0000 0000 0000 0000
# ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> fellow Indian <unk> <unk> Mauritius 1-0 from the first leg , they were held to a 1-1 draw at home on Saturday despite playing against 0000 men for most of the match .
# ['O', 'O', 'I-LOC', 'I-LOC', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'I-MISC', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# Philippoussis <unk> a match point at <unk> in the <unk> tie break before winning 6-3 3-6 7-6 ( 8-6 ) .
# ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> only hours after Chinese state media said the time was right to <unk> in political talks with Taiwan , Foreign Ministry spokesman <unk> <unk> told Reuters : " The <unk> <unk> for the opening of the talks has been <unk> by the Taiwan authorities . "
# ['O', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'I-ORG', 'I-ORG', 'O', 'I-PER', 'I-PER', 'O', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'I-ORG', 'I-ORG', 'O', 'I-PER', 'I-PER', 'O', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O']
#
#
#
# 14. <unk> 0000 0000 - 0000 0000 0000 0000
# ['O', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# SOCCER - <unk> 'S <unk> <unk> ' <unk> <unk> <unk> FOR <unk> .
# ['O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'O']
# ['O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O']
#
#
#
# <unk> 1996-12-07
# ['I-LOC', 'O']
# ['I-LOC', 'O']
#
#
#
# The Greek <unk> party 's executive bureau gave the <unk> light to Prime Minister <unk> <unk> to call <unk> elections , its general secretary <unk> <unk> told reporters .
# ['O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O']
# ['O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O']
#
#
#
# It was the second arms <unk> this week .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> <unk> <unk> - <unk> C 0000 OF <unk> 0000 , 0000 .
# ['I-ORG', 'I-ORG', 'O', 'O', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-ORG', 'I-ORG', 'I-ORG', 'O', 'I-PER', 'O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'O']
#
#
#
# Brooks 0000 0000 0000 0000 , Nick Faldo ( Britain ) 0000 0000 0000 0000
# ['I-PER', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O']
# ['I-PER', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O']
#
#
#
# Peter <unk>
# ['I-PER', 'I-PER']
# ['I-PER', 'O']
#
#
#
# A human rights <unk> said on Wednesday he had been released after more than two weeks in <unk> that followed his call for an <unk> into the death of a Gaza man <unk> by Palestinian police .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'I-MISC', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'I-MISC', 'O', 'O']
#
#
#
# <unk> <unk>
# ['I-ORG', 'I-ORG']
# ['O', 'I-ORG']
#
#
#
# As an <unk> , Albright <unk> and <unk> on Europe 's <unk> century problems before <unk> U.S. ambassador to the United Nations .
# ['O', 'O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'I-ORG', 'I-ORG', 'O']
# ['O', 'O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'I-LOC', 'I-ORG', 'O']
#
#
#
# " <unk> is getting stronger and stronger , and it already has <unk> of 0000 <unk> ( 0000 kph ) , " said <unk> <unk> <unk> <unk> .
# ['O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O']
# ['O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O']
#
#
#
# He is not as <unk> as he used to be be but was too good for me in the end .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# South Africa - 0000 - Andre Joubert , 0000 - Justin <unk> , 0000 - <unk> <unk> ( <unk> <unk> , 0000 <unk> ) 0000 - <unk> van <unk> , 0000 - <unk> <unk> ; 0000 - Henry <unk> , 0000 - <unk> van der <unk> ; 0000 - Gary <unk> ( captain ) , 0000 - Andre <unk> ( <unk> <unk> , 0000 ) , 0000 - <unk> <unk> , 0000 - Mark <unk> ( <unk> van <unk> , 0000 ) , 0000 - <unk> <unk> , 0000 - <unk> <unk> , 0000 - James <unk> , 0000 - <unk> <unk> ( <unk> <unk> , 0000 ) .
# ['I-LOC', 'I-LOC', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O']
# ['I-LOC', 'I-LOC', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O']
#
#
#
# <unk> said books by other <unk> , including British <unk> <unk> <unk> , were also <unk> .
# ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']
# ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> police shot dead six <unk> suspects as they tried to escape from <unk> in the northern city of <unk> , the national news agency reported on Friday .
# ['I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> 1996-08-24
# ['I-LOC', 'O']
# ['I-LOC', 'O']
#
#
#
# <unk> were <unk> in the money market but <unk> in bonds .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> 's own export performance was <unk> better than in <unk> on account of a 0000 percent rise in exports to Nepal and the opening of a new market - Sri Lanka , he said .
# ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O']
# ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O']
#
#
#
# 9. <unk> 0000
# ['O', 'I-PER', 'O']
# ['O', 'I-ORG', 'O']
#
#
#
# <unk> 1996-12-06
# ['I-LOC', 'O']
# ['I-LOC', 'O']
#
#
#
# TENNIS - <unk> <unk> <unk> - <unk> <unk> <unk> <unk> <unk> AT U.S. OPEN .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'I-MISC', 'O']
# ['O', 'O', 'O', 'I-ORG', 'O', 'O', 'I-PER', 'O', 'O', 'I-ORG', 'I-ORG', 'O', 'I-MISC', 'I-MISC', 'O']
#
#
#
# The man , doing his rounds in the northern city of <unk> on the day when German children <unk> <unk> small <unk> from <unk> <unk> , convinced police eventually that he was <unk> .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# All <unk> 's Association secretary N.J. <unk> said the strike would continue <unk> and the fishermen would block road and rail traffic if their <unk> were not met .
# ['I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'I-ORG', 'O', 'I-ORG', 'O', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> organisers said the <unk> <unk> remained <unk> but it would probably take about a month to <unk> an <unk> college which could also hold several rounds of <unk> before a clear winner <unk> .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# ATHLETICS - <unk> <unk> <unk> WORLD RECORD IN 0000 <unk> .
# ['O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> <unk> snapped by cool passenger .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# Bank of New Zealand said on Thursday it was <unk> its <unk> home lending rates .
# ['I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-ORG', 'I-ORG', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# Qualifier vs. qualifier
# ['O', 'O', 'O']
# ['O', 'O', 'O']
#
#
#
# <unk> , 0000 , had complained of lower back <unk> since a trip to Taiwan in May , when <unk> forced her to go to <unk> <unk> <unk> for an <unk> .
# ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O']
# ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O']
#
#
#
# <unk> <unk> 0000 <unk> Moscow 0000
# ['I-ORG', 'I-ORG', 'O', 'I-ORG', 'I-ORG', 'O']
# ['I-ORG', 'I-ORG', 'O', 'I-ORG', 'I-ORG', 'O']
#
#
#
# -- Wellington newsroom 0000 0000 0000 0000
# ['O', 'I-LOC', 'O', 'O', 'O', 'O', 'O']
# ['O', 'I-LOC', 'O', 'O', 'O', 'O', 'O']
#
#
#
# -DOCSTART-
# ['O']
# ['O']
#
#
#
# <unk> , West Bank 1996-08-28
# ['I-LOC', 'O', 'I-LOC', 'I-LOC', 'O']
# ['I-LOC', 'O', 'I-LOC', 'I-LOC', 'O']
#
#
#
# -DOCSTART-
# ['O']
# ['O']
#
#
#
# -DOCSTART-
# ['O']
# ['O']
#
#
#
# 1. <unk> <unk> ( Italy ) <unk> ( world record )
# ['O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# PARIS 1996-08-24
# ['I-LOC', 'O']
# ['I-LOC', 'O']
#
#
#
# <unk> was a key player in President Bill Clinton 's failed attempt at sweeping <unk> changes but when he <unk> <unk> leader he declared he would be no <unk> for the White House .
# ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'I-LOC', 'O']
# ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'I-LOC', 'O']
#
#
#
# W D L G / F G / A <unk>
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# The ministers agreed at Tuesday 's cabinet meeting to step up <unk> measures for school <unk> in September and October , when <unk> around the country resume .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# The victory against Japan <unk> the Fed Cup debut of Monica Seles , who <unk> a <unk> U.S. citizen in 0000 .
# ['O', 'O', 'O', 'I-LOC', 'O', 'O', 'I-MISC', 'I-MISC', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'I-LOC', 'O', 'O', 'I-MISC', 'I-MISC', 'O', 'I-ORG', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O']
#
#
#
# -DOCSTART-
# ['O']
# ['O']
#
#
#
# A note with the <unk> demand was left in the couple 's car , which was used in the kidnapping , <unk> told a news conference on Monday .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# 5. Steve Brown ( U.S. ) <unk>
# ['O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O']
# ['O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O']
#
#
#
# The <unk> said <unk> <unk> had also been used to film the couple and that a <unk> <unk> .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# Iran 's <unk> representative to the United Nations , <unk> <unk> <unk> , made the <unk> in a letter to U.N. <unk> <unk> <unk> on Friday , the agency said .
# ['I-LOC', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'I-ORG', 'O', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-LOC', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'I-ORG', 'O', 'I-ORG', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> 1996-08-26
# ['I-LOC', 'O']
# ['I-LOC', 'O']
#
#
#
# Extras ( nb-8 ) 0000
# ['O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O']
#
#
#
# - <unk> 0000 down <unk>
# ['O', 'I-LOC', 'O', 'O', 'O']
# ['O', 'I-ORG', 'O', 'O', 'O']
#
#
#
# In one letter , a black <unk> <unk> South <unk> his wife , " <unk> great is the <unk> national <unk> yet I look forward to a <unk> day when I <unk> have the <unk> of seeing you in the full <unk> of freedom .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# -DOCSTART-
# ['O']
# ['O']
#
#
#
# <unk> <unk> <unk> remain <unk> for the <unk> of <unk> in the region .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# Some <unk> <unk> <unk> <unk> they can actually <unk> to such a point that they fly .
# ['O', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# Rudar 0000 0000 0000 0000 0000 0000 0000
# ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> 0000 0000 0000 0000 0000 0000
# ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# The <unk> Woods , who turned <unk> Tuesday after winning an <unk> third successive U.S. <unk> <unk> , <unk> on the front nine , <unk> the first and seventh <unk> and <unk> the <unk> , <unk> ninth <unk> .
# ['O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# The <unk> will visit <unk> before <unk> in the Chinese capital , Beijing , early next week , officials said .
# ['O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'I-ORG', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> Moscow ( Russia ) 0000 0000 0000 0000
# ['I-ORG', 'I-ORG', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O']
# ['I-ORG', 'I-ORG', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> newspapers said the men had been <unk> against " strategic <unk> and <unk> <unk> " but gave no other details .
# ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# On Tuesday night , Kevorkian <unk> the death of <unk> <unk> , a <unk> Texas woman with <unk> <unk> <unk> , or <unk> <unk> 's disease .
# ['O', 'O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'I-PER', 'I-LOC', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O']
#
#
#
# <unk> Abu <unk> , said <unk> Ministry <unk> had told him to <unk> all the <unk> of the August <unk> back to Cyprus at his own <unk> .
# ['I-PER', 'I-PER', 'I-PER', 'O', 'O', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O']
# ['I-PER', 'I-PER', 'I-PER', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O']
#
#
#
# But spending on <unk> products increased <unk> to a rate of $ <unk> trillion from $ <unk> trillion in June , while spending for services was up to $ <unk> trillion in July from $ <unk> trillion .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# 8. Michael <unk> ( Germany ) <unk>
# ['O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O']
# ['O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O']
#
#
#
# <unk> win 2-1 on aggregate .
# ['I-ORG', 'O', 'O', 'O', 'O', 'O']
# ['I-ORG', 'O', 'O', 'O', 'O', 'O']
#
#
#
# Barbara <unk> ( Germany ) beat 0000 - <unk> <unk> (
# ['I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O']
# ['I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O']
#
#
#
# <unk> Real Madrid <unk>
# ['O', 'I-ORG', 'I-ORG', 'O']
# ['O', 'I-ORG', 'I-ORG', 'I-ORG']
#
#
#
# More <unk> results are expected soon .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# 0000 - <unk> <unk>
# ['O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O']
#
#
#
# 0000 - British <unk> Alan John <unk> ( <unk> ) Taylor died .
# ['O', 'O', 'I-MISC', 'O', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O']
# ['O', 'O', 'I-MISC', 'O', 'O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'I-PER', 'O', 'O']
#
#
#
# 15. <unk> <unk> ( South Africa ) <unk>
# ['O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'I-LOC', 'O', 'O']
# ['O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'I-LOC', 'O', 'O']
#
#
#
# 0000 - <unk> <unk> ( South Africa ) beat Todd <unk>
# ['O', 'O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'I-LOC', 'O', 'O', 'I-PER', 'I-PER']
# ['O', 'O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'I-LOC', 'O', 'O', 'I-PER', 'I-PER']
#
#
#
# <unk> <unk> 0000 - <unk> 0000 : <unk> of <unk> at $ <unk> , 10,000 of <unk> at $ <unk> , <unk> of <unk> at $ <unk> .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O']
#
#
#
# " Three of the four children had <unk> 's disease , " <unk> 's group <unk> in the <unk> medical <unk> .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O']
#
#
#
# <unk> <unk> of Finland , driving a <unk> , on Monday won the 1,000 Lakes Rally , sixth round of the world championship .
# ['I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O', 'O', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# Company <unk> <unk> <unk> Inc
# ['O', 'I-MISC', 'I-ORG', 'I-ORG', 'I-ORG']
# ['O', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG']
#
#
#
# <unk> <unk> 0000 0000 loss 0000 0000 profit
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> San Diego has won seven of its last eight games and improved to <unk> against <unk> East <unk> .
# ['O', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'I-MISC', 'O', 'O']
# ['I-ORG', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-LOC', 'O', 'O']
#
#
#
# Results of South Korean
# ['O', 'O', 'I-MISC', 'I-MISC']
# ['O', 'O', 'I-MISC', 'I-MISC']
#
#
#
# -DOCSTART-
# ['O']
# ['O']
#
#
#
# -- Bangkok newsroom <unk>
# ['O', 'I-LOC', 'O', 'O']
# ['O', 'I-MISC', 'O', 'O']
#
#
#
# ( <unk> ) 7-6 ( 7-4 )
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> <unk> ( Romania ) beat <unk> <unk> ( Germany ) 6-3 6-2
# ['I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O', 'O']
# ['I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O', 'O']
#
#
#
# LOS ANGELES <unk>
# ['I-ORG', 'I-ORG', 'O']
# ['I-ORG', 'I-ORG', 'O']
#
#
#
# As often , the most volume was in <unk> .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O']
#
#
#
# <unk> <unk> 0000 <unk> <unk> 0000
# ['I-ORG', 'I-ORG', 'O', 'I-ORG', 'I-ORG', 'O']
# ['I-ORG', 'I-ORG', 'O', 'I-ORG', 'I-ORG', 'O']
#
#
#
# <unk> - <unk> <unk> ( <unk> ) , <unk> <unk>
# ['I-ORG', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER']
# ['I-ORG', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'I-ORG', 'I-ORG']
#
#
#
# - <unk> <unk> up <unk>
# ['O', 'I-LOC', 'O', 'O', 'O']
# ['O', 'I-LOC', 'O', 'O', 'O']
#
#
#
# Local officials said one policeman was killed by <unk> during clashes with <unk> students on Thursday .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# Zimbabwe on Monday :
# ['I-LOC', 'O', 'O', 'O']
# ['I-LOC', 'O', 'O', 'O']
#
#
#
# Aberdeen v Hearts
# ['I-ORG', 'O', 'I-ORG']
# ['I-ORG', 'O', 'I-ORG']
#
#
#
# -DOCSTART-
# ['O']
# ['O']
#
#
#
# Indian officials blame <unk> Moslem <unk> <unk> in <unk> for a string of <unk> in the city three months later that killed 0000 people .
# ['I-MISC', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-MISC', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# The PKK also <unk> into Turkey from <unk> in the <unk> of northern Iraq .
# ['O', 'I-ORG', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O']
# ['O', 'I-ORG', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O']
#
#
#
# SOCCER - <unk> FIRST DIVISION RESULTS .
# ['O', 'O', 'I-MISC', 'O', 'O', 'O', 'O']
# ['O', 'O', 'I-MISC', 'O', 'O', 'O', 'O']
#
#
#
# The <unk> American <unk> off the Stadium Court for <unk> of an upset stomach after his two and a half hour struggle against <unk> .
# ['O', 'O', 'I-MISC', 'O', 'O', 'O', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'O']
# ['O', 'O', 'I-MISC', 'O', 'O', 'O', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'O']
#
#
#
# Nigeria is under fire from many Western countries for human rights <unk> and lack of democracy .
# ['I-LOC', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-LOC', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# The popular <unk> is playing his final major tournament next week and the <unk> champion 's Grand Slam <unk> could well be a <unk> <unk> .
# ['O', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> <unk> <unk> ( Netherlands ) <unk> <unk>
# ['O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'I-ORG', 'O']
# ['O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'I-ORG', 'O']
#
#
#
# -DOCSTART-
# ['O']
# ['O']
#
#
#
# <unk> <unk> <unk>
# ['O', 'O', 'O']
# ['O', 'I-PER', 'O']
#
#
#
# Middlesbrough 0000 0000 0000 0000 0000 0000 0000
# ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> David <unk> , who <unk> <unk> , told the Sun : " There is a risk he could be <unk> in the eye if he steps into the ring again .
# ['O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> - <unk> <unk> figures <unk> to value of orders on books at end of period .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# Hong Kong 's Tsang sees growth , <unk> <unk> .
# ['I-LOC', 'I-LOC', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-LOC', 'I-LOC', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# BASEBALL - RESULTS OF S. <unk> <unk> GAMES .
# ['O', 'O', 'O', 'O', 'I-MISC', 'I-MISC', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O']
#
#
#
# 8. <unk> <unk> ( Kenya ) <unk>
# ['O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O']
# ['O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O']
#
#
#
# England
# ['I-LOC']
# ['I-LOC']
#
#
#
# <unk> United 0000 <unk> 0000
# ['I-ORG', 'I-ORG', 'O', 'I-ORG', 'O']
# ['I-ORG', 'I-ORG', 'O', 'I-ORG', 'O']
#
#
#
# 9. Britain I ( <unk> <unk> , <unk> <unk> ) <unk> ( <unk>
# ['O', 'I-ORG', 'I-ORG', 'O', 'I-PER', 'I-PER', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O']
# ['O', 'I-LOC', 'O', 'O', 'I-PER', 'I-PER', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O']
#
#
#
# ATLANTA AT NEW <unk>
# ['I-ORG', 'O', 'I-LOC', 'I-LOC']
# ['I-ORG', 'O', 'I-LOC', 'I-LOC']
#
#
#
# German <unk> <unk> of motor <unk> jumped <unk> percent in July this year from the <unk> period , the Federal office for motor <unk> said on Thursday .
# ['I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O']
# ...
# ['O', 'O', 'O', 'O', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'I-ORG', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'I-ORG', 'O', 'O']
#
#
#
# He said that despite the new law , Wisconsin will still <unk> federal <unk> allowing the working poor to <unk> health <unk> <unk> from the state , a <unk> <unk> <unk> for <unk> in the welfare program , and child support <unk> to go <unk> to <unk> <unk> .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# GLASGOW 1996-12-07
# ['I-LOC', 'O']
# ['I-LOC', 'O']
#
#
#
# EPS loss <unk> yen vs loss <unk> yen
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# CHICAGO 1996-08-26
# ['I-LOC', 'O']
# ['I-LOC', 'O']
#
#
#
# <unk> ( <unk> <unk> ) <unk> 0000
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-ORG', 'O', 'O', 'O', 'O', 'I-ORG', 'O']
#
#
#
# Scores : Australia <unk> in 0000 overs , Sri Lanka <unk> in <unk> overs .
# ['O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O']
#
#
#
# No arrests had been made , a police spokesman said .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# Last season 's league and Cup winners Manchester United host 0000 champions Blackburn on Sunday .
# ['O', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'I-ORG', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'I-ORG', 'O', 'O', 'O']
#
#
#
# <unk> 0000 <unk> 0000
# ['I-ORG', 'O', 'I-ORG', 'O']
# ['I-ORG', 'O', 'I-ORG', 'O']
#
#
#
# U.S. <unk> <unk> fire while landing in Israel .
# ['I-LOC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O']
# ['I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O']
#
#
#
# -DOCSTART-
# ['O']
# ['O']
#
#
#
# <unk> 0000 <unk> 0000
# ['I-ORG', 'O', 'I-ORG', 'O']
# ['I-ORG', 'O', 'I-ORG', 'O']
#
#
#
# Extras ( <unk> <unk> <unk> ) 0000
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# Both <unk> were in the <unk> <unk> region of <unk> , about 0000 miles ( 0000 <unk> ) southeast of <unk> <unk> , and were located within three miles of one another .
# ['O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# " I <unk> this year , that without <unk> <unk> percent of your <unk> into tennis , I do n't think you can <unk> , " said the <unk> <unk> .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'O']
#
#
#
# Following are some of the main stories in Tuesday 's Sri Lankan newspapers :
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'I-MISC', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'I-MISC', 'O', 'O']
#
#
#
# <unk> AG won <unk> <unk> , slightly more than a quarter of the total .
# ['I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# SOCCER - FRENCH LEAGUE STANDINGS .
# ['O', 'O', 'I-MISC', 'O', 'O', 'O']
# ['O', 'O', 'I-MISC', 'O', 'O', 'O']
#
#
#
# <unk> has <unk> political leaders to a meeting on Thursday to discuss the final form of the <unk> which both <unk> and <unk> <unk> <unk> for different <unk> .
# ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'O', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> , Belgium 1996-08-25
# ['I-LOC', 'O', 'I-LOC', 'O']
# ['I-LOC', 'O', 'I-LOC', 'O']
#
#
#
# Interfax news agency said police had <unk> one of the <unk> .
# ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# * President Clinton <unk> <unk> plan to <unk> up toxic waste <unk> .
# ['O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# 0000 - <unk> Khan ( Pakistan ) beat Simon <unk> ( Germany ) 15-12 15-7 <unk> 15-10
# ['O', 'O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O']
#
#
#
# Anwar , who struck a <unk> 0000 at The Oval , was the more <unk> as he made 0000 from 0000 balls before <unk> a <unk> off Irani to <unk> at <unk> .
# ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'O', 'I-PER', 'O', 'O', 'O']
# ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> that a new Treasury secretary might favour a return to <unk> policy could <unk> <unk> for financial markets .
# ['O', 'O', 'O', 'O', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# South African company results expected next week include the
# ['I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# 7. <unk> 0000
# ['O', 'I-ORG', 'O']
# ['O', 'I-ORG', 'O']
#
#
#
# <unk>
# ['I-LOC']
# ['O']
#
#
#
# Some Palestinians took to back <unk> , only to run into waiting Israeli security forces .
# ['O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'O']
# ['O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'O']
#
#
#
# King <unk> left Nepal on Friday for a <unk> visit to China , his eighth since <unk> the <unk> in 0000 , officials said .
# ['O', 'I-PER', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# 3. <unk> <unk> ( Germany ) <unk>
# ['O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O']
# ['O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O']
#
#
#
# SOCCER - <unk> <unk> <unk> FIRST ROUND <unk> .
# ['O', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> said they thought the aircraft was <unk> with too much <unk> .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> , <unk> 1996-08-23
# ['I-LOC', 'O', 'I-LOC', 'O']
# ['I-LOC', 'O', 'I-LOC', 'O']
#
#
#
# CALIFORNIA 0000 0000 <unk> 0000
# ['I-ORG', 'O', 'O', 'O', 'O']
# ['I-ORG', 'O', 'O', 'O', 'O']
#
#
#
# <unk> <unk> ( 0000 ) <unk> 0000 .
# ['I-ORG', 'O', 'O', 'O', 'O', 'I-ORG', 'O', 'O']
# ['I-ORG', 'O', 'O', 'O', 'O', 'I-ORG', 'O', 'O']
#
#
#
# Nice are <unk> in the table .
# ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# She added , " But we need to do more .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# Summary of Thursday 's only
# ['O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O']
#
#
#
# A hijacked Sudan Airways plane with 0000 passengers and crew on board was expected to land at London 's Stansted airport later on Tuesday morning , a police spokeswoman said .
# ['O', 'O', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# Newmont , in fact , will not <unk> from the Santa Fe acquisition on an earnings basis for at least two years , which also <unk> its <unk> to <unk> its offer .
# ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# ATLANTA AT PITTSBURGH
# ['I-ORG', 'O', 'I-LOC']
# ['I-ORG', 'O', 'I-LOC']
#
#
#
# <unk>
# ['O']
# ['O']
#
#
#
# Salim Malik 0000 not out , Ijaz Ahmed 0000 )
# ['I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O']
# ['I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O']
#
#
#
# <unk> kills Polish <unk> <unk> , <unk> husband .
# ['O', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# Council speaker Ahmed <unk> said the decision was part of a <unk> plan to <unk> Israeli settlement policy , land <unk> and what he <unk> other violations of the <unk> peace deals .
# ['O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'O']
# ['I-ORG', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'O']
#
#
#
# Roe said he was <unk> by his forecast of a <unk> billion <unk> net for 0000 .
# ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# It was <unk> to reporters at the press centre of Clinton 's Democratic convention headquarters just hours before the president was to address the delegates <unk> the party 's nomination for a second <unk> term in the White House .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'I-LOC', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'I-LOC', 'O']
#
#
#
# ( in millions of <unk> unless stated )
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# -DOCSTART-
# ['O']
# ['O']
#
#
#
# <unk> leader M. <unk> says it is <unk> to talk to <unk> about peace <unk> and that the government should submit peace plan to parliament very soon .
# ['O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-ORG', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> <unk> gets the opportunity to enter the next <unk> with such a big <unk> has got to be seen as a strong message to the industry . "
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> <unk> ( <unk> , <unk> , <unk> ) , <unk> <unk> ( <unk> ) , Petr
# ['I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'I-PER']
# ['I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'I-PER']
#
#
#
# Halftime <unk> .
# ['O', 'O', 'O']
# ['O', 'O', 'O']
#
#
#
# COLORADO 0000 0000 <unk> 0000
# ['I-ORG', 'O', 'O', 'O', 'O']
# ['I-ORG', 'O', 'O', 'O', 'O']
#
#
#
# The defeat put the <unk> out of the <unk> Cup .
# ['O', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'O', 'I-MISC', 'I-MISC', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'I-MISC', 'O']
#
#
#
# " I was n't happy when I saw the draw .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# The American League Western leaders have won eight of 0000 games at <unk> <unk> , <unk> the Yankees as the only teams with a winning record at the <unk> Central leaders ' home .
# ['O', 'I-MISC', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O']
# ['O', 'I-MISC', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O']
#
#
#
# As Glenn <unk> , a <unk> Florida minister who is the victim 's father , looked on , <unk> was <unk> dead at <unk> a.m. <unk> ( 0000 GMT ) for the murder of <unk> <unk> .
# ['O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O']
# ['O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'I-LOC', 'O']
#
#
#
# I just hit through and I was <unk> the air before the ball got there .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# China says time right for Taiwan talks .
# ['I-LOC', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O']
# ['I-LOC', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O']
#
#
#
# <unk> <unk> <unk> Grand Prix on Sunday :
# ['I-MISC', 'O', 'O', 'I-MISC', 'I-MISC', 'O', 'O', 'O']
# ['O', 'O', 'O', 'I-MISC', 'I-MISC', 'O', 'O', 'O']
#
#
#
# Under the revised <unk> state spending is expected to rise by some 0000 billion lei .
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# Turkish troops killed 0000 Kurdish rebels in recent clashes in the east of the country , security officials said on Wednesday .
# ['I-MISC', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-MISC', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# W D L G / F G / A <unk>
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
#
# <unk> <unk> futures ended <unk> but off the day 's <unk> on Thursday .
# ['I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
