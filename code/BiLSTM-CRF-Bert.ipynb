# %% [markdown]
# # CSE 291 Assignment 2 BiLSTM CRF

# %% [markdown]
# ## Download Data/Eval Script

# %%
# !wget https://raw.githubusercontent.com/sighsmile/conlleval/master/conlleval.py
# !wget https://raw.githubusercontent.com/tberg12/cse291spr21/main/assignment2/train.data.quad
# !wget https://raw.githubusercontent.com/tberg12/cse291spr21/main/assignment2/dev.data.quad

# %%
# !pip install pytorch-transformers
# !pip install -U numpy
# Out:
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (1.20.3)
# WARNING: You are using pip version 21.1.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/opt/conda/bin/python3.7 -m pip install --upgrade pip' command.

# %%
import torch
from pytorch_transformers import BertTokenizer
from pytorch_transformers import BertModel## Load pretrained model/tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
bertmodel = BertModel.from_pretrained('bert-base-uncased',
                                  output_hidden_states = True, # Whether the model returns all hidden-states.
                                  )


def get_word_embedding(marked_text):

    # Tokenize our sentence with the BERT tokenizer.
    tokenized_text = [word.lower() for word in marked_text.split(" ")]

    # Map the token strings to their vocabulary indeces.
    indexed_tokens = tokenizer.convert_tokens_to_ids(tokenized_text)
    
    segments_ids = [1] * len(tokenized_text)

    tokens_tensor = torch.tensor([indexed_tokens])
    
    segments_tensors = torch.tensor([segments_ids])
    
    with torch.no_grad():

        outputs = bertmodel(tokens_tensor, segments_tensors)

        # Evaluating the model will return a different number of objects based on 
        # how it's  configured in the `from_pretrained` call earlier. In this case, 
        # becase we set `output_hidden_states = True`, the third item will be the 
        # hidden states from all layers. See the documentation for more details:
        # https://huggingface.co/transformers/model_doc/bert.html#bertmodel
        hidden_states = outputs[2]
        
        token_embeddings = torch.stack(hidden_states, dim=0)
        
        token_embeddings = torch.squeeze(token_embeddings, dim=1)

        token_embeddings = token_embeddings.permute(1,0,2)

        token_vecs_sum = []

        # `token_embeddings` is a [22 x 12 x 768] tensor.

        # For each token in the sentence...
        for token in token_embeddings:

            # `token` is a [12 x 768] tensor

            # Sum the vectors from the last four layers.
            sum_vec = torch.sum(token[-4:], dim=0)

            # Use `sum_vec` to represent `token`.
            token_vecs_sum.append(sum_vec)
        
        
        return token_vecs_sum

# %%
import conlleval
from tqdm import tqdm
import numpy as np
from collections import defaultdict, Counter
import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.optim as optim
from torchtext.vocab import Vocab
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
import pdb 
from sklearn.metrics import precision_recall_fscore_support


torch.manual_seed(291)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# ## Data Preparation

# %%
TRAIN_DATA = 'train.data.quad'
VALID_DATA = 'dev.data.quad'
UNK = '<unk>'
PAD = '<pad>'
START_TAG = "<start>"  # you can add this explicitly or use it implicitly in your CRF layer
STOP_TAG = "<stop>"    # you can add this explicitly or use it implicitly in your CRF layer


def read_conll_sentence(path):
    """ Read a CONLL-format sentence into vocab objects
    Args:
        :param path: path to CONLL-format data file
        :param word_vocab: Vocabulary object for source
        :param label_vocab: Vocabulary object for target
    """
    sent = [[], []]
    with open(path) as f:
        for line in f:
            line = line.strip().split()
            if line:
                # replace numbers with 0000
                word = line[0]
                word = '0000' if word.isnumeric() else word
                sent[0].append(word)
                sent[1].append(line[3])
            else:
                yield sent[0], sent[1]
                sent = [[], []]



def prepare_dataset(dataset, word_vocab, label_vocab):
    dataset = [
      [
        torch.tensor([word_vocab.stoi[word] for word in sent[0]], dtype=torch.long),
        torch.tensor([label_vocab.stoi[label] for label in sent[1]], dtype=torch.long),
      ]
      for sent in dataset
    ]
    return dataset


# load a list of sentences, where each word in the list is a tuple containing the word and the label
train_data = list(read_conll_sentence(TRAIN_DATA))
train_word_counter = Counter([word for sent in train_data for word in sent[0]])
train_label_counter = Counter([label for sent in train_data for label in sent[1]])
word_vocab = Vocab(train_word_counter, specials=(UNK, PAD), min_freq=2)
label_vocab = Vocab(train_label_counter, specials=(), min_freq=1)
print(train_data[0])

train_raw_sent = [" ".join(sent[0]) for sent in train_data]

train_data = prepare_dataset(train_data, word_vocab, label_vocab)
print('Train word vocab:', len(word_vocab), 'symbols.')
print('Train label vocab:', len(label_vocab), f'symbols: {list(label_vocab.stoi.keys())}')
valid_data = list(read_conll_sentence(VALID_DATA))

val_raw_sent = [" ".join(sent[0]) for sent in valid_data]

valid_data = prepare_dataset(valid_data, word_vocab, label_vocab)
print('Train data:', len(train_data), 'sentences.')
print('Valid data:', len(valid_data))

print(' '.join([word_vocab.itos[i.item()] for i in train_data[1][0]]))
print(' '.join([label_vocab.itos[i.item()] for i in train_data[1][1]]))

print(' '.join([word_vocab.itos[i.item()] for i in valid_data[1][0]]))
print(' '.join([label_vocab.itos[i.item()] for i in valid_data[1][1]]))
# Out:
# (['Pusan', '0000', '0000', '0000', '0000', '0000', '0000'], ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O'])
# Train word vocab: 3947 symbols.
# Train label vocab: 8 symbols: ['O', 'I-PER', 'I-ORG', 'I-LOC', 'I-MISC', 'B-MISC', 'B-ORG', 'B-LOC']
# Train data: 3420 sentences.
# Valid data: 800
# Martin Brooks , president of Miss Universe Inc , said he spoke with Machado to <unk> her that organisers were not <unk> pressure on her .
# I-PER I-PER O O O I-ORG I-ORG I-ORG O O O O O I-PER O O O O O O O O O O O O
# Earlier this month , <unk> denied a Kabul government statement that the two sides had agreed to a ceasefire in the north .
# O O O O I-PER O O I-LOC O O O O O O O O O O O O O O O

# %%
embeddingTrainDict = {}

for i, (sent, tags) in enumerate(train_data):
    
    embeddingTrainDict[i] = torch.vstack(get_word_embedding(train_raw_sent[i])).unsqueeze(0).to(device)

embeddingValDict = {}

for i, (sent, tags) in enumerate(valid_data):
    
    embeddingValDict[i] = torch.vstack(get_word_embedding(val_raw_sent[i])).unsqueeze(0).to(device)

# %%
train_raw_sent[1], tokenizer.tokenize(train_raw_sent[1])
# Out:
# ('Martin Brooks , president of Miss Universe Inc , said he spoke with Machado to assure her that organisers were not putting pressure on her .',
#  ['martin',
#   'brooks',
#   ',',
#   'president',
#   'of',
#   'miss',
#   'universe',
#   'inc',
#   ',',
#   'said',
#   'he',
#   'spoke',
#   'with',
#   'mach',
#   '##ado',
#   'to',
#   'assure',
#   'her',
#   'that',
#   'organise',
#   '##rs',
#   'were',
#   'not',
#   'putting',
#   'pressure',
#   'on',
#   'her',
#   '.'])

# %%
embeddingTrainDict[0].shape
# Out:
# torch.Size([1, 7, 768])

# %%
def log_sum_exp(vec):
    max_score = vec.max()
    max_score_broadcast = max_score.view(1, -1).expand(1, vec.size()[1])
    return max_score + torch.log(torch.sum(torch.exp(vec - max_score_broadcast)))

# %% [markdown]
# ## BiLSTMTagger

# %%
class CRF():
    def __init__(self, vocab_size, tag_vocab_size):
        
        self.vocab_size = vocab_size
        self.tagset_size = tag_vocab_size

        self.transitions = nn.Parameter(
            torch.randn(self.tagset_size, self.tagset_size)).to(device)

        self.start_index = tag_vocab_size - 2
        self.end_index = tag_vocab_size - 1
        
        self.transitions.data[self.start_index, :] = -10000
        self.transitions.data[:, self.end_index] = -10000
        
    
    def _viterbi_decode(self, feats):
        backtrace = []
        alpha = torch.full((1, self.tagset_size), -10000.0, device=device)
        alpha[0][self.start_index] = 0
        feats = feats.squeeze(0)
#         pdb.set_trace()
        for feat in feats:
            t2 = (self.transitions.T + (feat)).T + alpha
            t3 = t2.max(dim=1).values
            alpha = t3 + (t2.T - t3).T.exp().sum(dim=1).log().view(1,-1)
            backtrace.append(t2.argmax(dim=1))

        vec = alpha.T + self.transitions[:, [self.end_index]]
        best_tag = vec.squeeze(1).argmax().item()
        optimal_path = [best_tag]
        
        seq = reversed(backtrace[1:])
        
        for bp in seq: 
            best_tag = bp[best_tag].item()
            optimal_path.append(best_tag)
        
        score = (vec - vec.max()).exp().sum(axis=0, keepdim=True).log() + vec.max()
        return score,[ optimal_path[::-1]] 
    
     
    def _forward_alg(self, feats):
        init_alphas = torch.full((1, self.tagset_size), -10000.)

        init_alphas[0][self.start_index] = 0.


        forward_var = init_alphas.to(device)

        feats = feats.squeeze(0)

        for feat in feats:
            alphas_t = []  # The forward tensors at this timestep
            t2 = (self.transitions.T + (feat)).T + forward_var
            t3 = t2.max(dim=1).values
            forward_var = t3 + (t2.T - t3).T.exp().sum(dim=1).log().view(1,-1)

        terminal_var = forward_var + self.transitions[self.end_index]
        alpha = log_sum_exp(terminal_var)
        return alpha
    
    
    def _score_sentence(self, feats, tags):

        score = torch.zeros(1).to(device)
        feats = feats.squeeze(0)
        tags = tags.squeeze(0)
        tags = torch.cat([torch.tensor([self.start_index], dtype=torch.long).to(device), tags]).to(device)
        for i, feat in enumerate(feats):
            score = score + self.transitions[tags[i + 1], tags[i]] + feat[tags[i + 1]]

        score = score + self.transitions[self.end_index, tags[-1]]
        return score

# %%
# Starter code implementing a BiLSTM Tagger
# which makes locally normalized, independent
# tag classifications at each time step

class BiLSTMTagger(nn.Module):
    def __init__(self, vocab_size, tag_vocab_size, embedding_dim, hidden_dim, dropout=0.3):
        super(BiLSTMTagger, self).__init__()
        self.embedding_dim = embedding_dim
        self.hidden_dim = hidden_dim
        self.vocab_size = vocab_size
        self.tagset_size = tag_vocab_size
#         self.word_embeds = nn.Embedding(vocab_size, embedding_dim).to(device)
        self.bilstm = nn.LSTM(embedding_dim, hidden_dim // 2,
                            num_layers=1, bidirectional=True, batch_first=True).to(device)
        self.tag_projection_layer = nn.Linear(hidden_dim, self.tagset_size).to(device)
        self.dropout = nn.Dropout(p=dropout)

        self.crf = CRF(vocab_size, tag_vocab_size)


    def init_hidden(self):
        return (torch.randn(2, 1, self.hidden_dim // 2).to(device),
                torch.randn(2, 1, self.hidden_dim // 2).to(device))

    def compute_lstm_emission_features(self, sentence, embedding):
        hidden = self.init_hidden()
        embeds = self.dropout(embedding)
        bilstm_out, hidden = self.bilstm(embeds, hidden)
        bilstm_out = self.dropout(bilstm_out)
        bilstm_out = bilstm_out
        bilstm_feats = self.tag_projection_layer(bilstm_out)
        return bilstm_feats

     
    def forward(self, sentence, embedding):
        bilstm_feats = self.compute_lstm_emission_features(sentence, embedding)

        return self.crf._viterbi_decode(bilstm_feats)
  
    def loss(self, sentence, tags, embedding):
        feats = self.compute_lstm_emission_features(sentence, embedding)
        forward_score = self.crf._forward_alg(feats)
        gold_score = self.crf._score_sentence(feats, tags)
        return forward_score - gold_score

# %% [markdown]
# ## Train / Eval loop

# %%
def train(model, train_data, valid_data, word_vocab, label_vocab, epochs, log_interval=25):
    losses_per_epoch = []
    for epoch in range(epochs):
        print(f'--- EPOCH {epoch} ---')
        model.train()
        losses_per_epoch.append([])
        for i, (sent, tags) in enumerate(train_data):
            model.zero_grad()
            sent, tags = sent.to(device), tags.to(device)
            sent = sent.unsqueeze(0)
            tags = tags.unsqueeze(0)
            loss = model.loss(sent, tags, embeddingTrainDict[i])
            loss.backward()
            optimizer.step()

            losses_per_epoch[-1].append(loss.detach().cpu().item())
            if i > 0 and i % log_interval == 0:
                print(f'Avg loss over last {log_interval} updates: {np.mean(losses_per_epoch[-1][-log_interval:])}')

        evaluate(model, valid_data, word_vocab, label_vocab)


def evaluate(model, dataset, word_vocab, label_vocab):
    model.eval()
    losses = []
    scores = []
    true_tags = []
    pred_tags = []
    sents = []
    for i, (sent, tags) in enumerate(dataset):
        if i == 0:
            pass
        with torch.no_grad():
            sent, tags = sent.to(device), tags.to(device)
            sent = sent.unsqueeze(0)
            tags = tags.unsqueeze(0)
            losses.append(model.loss(sent, tags, embeddingValDict[i]).cpu().detach().item())
            score, pred_tag_seq = model(sent, embeddingValDict[i])
            scores.append(score)
            try:
                true_tags.append([label_vocab.itos[i] for i in tags.tolist()[0]])
                pred_tags.append([ label_vocab.itos[0] if i == 9 else label_vocab.itos[i] for i in pred_tag_seq[0]])
            except:
                print(pred_tag_seq)
                pass

            sents.append([word_vocab.itos[i] for i in sent[0]])

    print('Avg evaluation loss:', np.mean(losses))
    a = [tag for tags in true_tags for tag in tags]
    b = [tag for tags in pred_tags for tag in tags]
    print(conlleval.evaluate(a, b, verbose=True))


    scores_token = precision_recall_fscore_support(a,b, average=None, labels=label_vocab.itos)
    for i in range(len(label_vocab.itos)):
        print(label_vocab.itos[i] , "precision", scores_token[0][i], "recall", scores_token[1][i], "f1", scores_token[2][i], "count", scores_token[3][i])

#     print('\n5 random evaluation samples:')
#     for i in np.random.randint(0, len(sents), size=2):
#         print('SENT:', ' '.join(sents[i]))
#         print('TRUE:', ' '.join(true_tags[i]))
#         print('PRED:', ' '.join(pred_tags[i]))
    return sents, true_tags, pred_tags

# %% [markdown]
# ## Training

# %%
# Train BiLSTM Tagger Baseline
model = BiLSTMTagger(len(word_vocab), len(label_vocab)+2, 768, 256).to(device)


optimizer = optim.Adam(model.parameters(), lr=1e-3)
train(model, train_data, valid_data, word_vocab, label_vocab, epochs=10, log_interval=500)
# Out:
# --- EPOCH 0 ---
# Avg loss over last 500 updates: 7.185383933067322
# Avg loss over last 500 updates: 5.238719256401062
# Avg loss over last 500 updates: 4.438768275260926
# Avg loss over last 500 updates: 4.228360407352447
# Avg loss over last 500 updates: 4.062265147686005
# Avg loss over last 500 updates: 4.0703121407032015
# Avg evaluation loss: 4.02682015940547
# processed 11170 tokens with 1231 phrases; found: 829 phrases; correct: 523.
# accuracy:  51.10%; (non-O)
# accuracy:  91.32%; precision:  63.09%; recall:  42.49%; FB1:  50.78
#               LOC: precision:  81.17%; recall:  53.44%; FB1:  64.45  239
#              MISC: precision:  63.64%; recall:  25.52%; FB1:  36.43  77
#               ORG: precision:  43.59%; recall:  27.69%; FB1:  33.86  195
#               PER: precision:  61.32%; recall:  52.85%; FB1:  56.77  318
# (63.08805790108565, 42.48578391551584, 50.77669902912621)
# O precision 0.9247033010870649 recall 0.9912336968141972 f1 0.9568133739229142 count 9354
# I-PER precision 0.8476953907815631 recall 0.6630094043887147 f1 0.7440633245382586 count 638
# I-ORG precision 0.6807817589576547 recall 0.42653061224489797 f1 0.5244667503136763 count 490
# I-LOC precision 0.8914728682170543 recall 0.5476190476190477 f1 0.6784660766961652 count 420
# I-MISC precision 0.8354430379746836 recall 0.2509505703422053 f1 0.38596491228070173 count 263
# B-MISC precision 0.0 recall 0.0 f1 0.0 count 1
# B-ORG precision 0.0 recall 0.0 f1 0.0 count 0
# B-LOC precision 0.0 recall 0.0 f1 0.0 count 4
# --- EPOCH 1 ---
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Avg loss over last 500 updates: 3.7595493021011355
# Avg loss over last 500 updates: 4.0923817048072815
# Avg loss over last 500 updates: 3.6457367897033692
# Avg loss over last 500 updates: 3.5603699798583985
# Avg loss over last 500 updates: 3.51646524477005
# Avg loss over last 500 updates: 3.605425795793533
# Avg evaluation loss: 3.8896447882056235
# processed 11170 tokens with 1231 phrases; found: 858 phrases; correct: 556.
# accuracy:  53.80%; (non-O)
# accuracy:  91.86%; precision:  64.80%; recall:  45.17%; FB1:  53.23
#               LOC: precision:  82.86%; recall:  55.92%; FB1:  66.78  245
#              MISC: precision:  58.76%; recall:  29.69%; FB1:  39.45  97
#               ORG: precision:  47.92%; recall:  29.97%; FB1:  36.87  192
#               PER: precision:  62.96%; recall:  55.28%; FB1:  58.87  324
# (64.80186480186481, 45.166531275385864, 53.231211105792255)
# O precision 0.927936031984008 recall 0.9925165704511439 f1 0.9591404514696007 count 9354
# I-PER precision 0.8772277227722772 recall 0.6943573667711599 f1 0.7751531058617672 count 638
# I-ORG precision 0.7361111111111112 recall 0.4326530612244898 f1 0.544987146529563 count 490
# I-LOC precision 0.8966789667896679 recall 0.5785714285714286 f1 0.703328509406657 count 420
# I-MISC precision 0.7821782178217822 recall 0.30038022813688214 f1 0.4340659340659341 count 263
# B-MISC precision 0.0 recall 0.0 f1 0.0 count 1
# B-ORG precision 0.0 recall 0.0 f1 0.0 count 0
# B-LOC precision 0.0 recall 0.0 f1 0.0 count 4
# --- EPOCH 2 ---
# Avg loss over last 500 updates: 3.4405703978538513
# Avg loss over last 500 updates: 3.723988374710083
# Avg loss over last 500 updates: 3.444680936336517
# Avg loss over last 500 updates: 3.473899556159973
# Avg loss over last 500 updates: 3.286563066005707
# Avg loss over last 500 updates: 3.4010513916015626
# Avg evaluation loss: 3.711030591726303
# processed 11170 tokens with 1231 phrases; found: 901 phrases; correct: 586.
# accuracy:  56.00%; (non-O)
# accuracy:  92.07%; precision:  65.04%; recall:  47.60%; FB1:  54.97
#               LOC: precision:  78.91%; recall:  59.78%; FB1:  68.03  275
#              MISC: precision:  60.92%; recall:  27.60%; FB1:  37.99  87
#               ORG: precision:  46.26%; recall:  34.20%; FB1:  39.33  227
#               PER: precision:  67.63%; recall:  57.18%; FB1:  61.97  312
# (65.03884572697002, 47.603574329813156, 54.971857410881796)
# O precision 0.9324813845844234 recall 0.9906991661321359 f1 0.9607091022185362 count 9354
# I-PER precision 0.8899803536345776 recall 0.7100313479623824 f1 0.7898866608544027 count 638
# I-ORG precision 0.6978851963746223 recall 0.4714285714285714 f1 0.5627283800243605 count 490
# I-LOC precision 0.858085808580858 recall 0.6190476190476191 f1 0.719225449515906 count 420
# I-MISC precision 0.8202247191011236 recall 0.27756653992395436 f1 0.41477272727272724 count 263
# B-MISC precision 0.0 recall 0.0 f1 0.0 count 1
# B-ORG precision 0.0 recall 0.0 f1 0.0 count 0
# B-LOC precision 0.0 recall 0.0 f1 0.0 count 4
# --- EPOCH 3 ---
# Avg loss over last 500 updates: 3.2059805996418
# Avg loss over last 500 updates: 3.462091413497925
# Avg loss over last 500 updates: 3.2425612049102783
# Avg loss over last 500 updates: 3.2487937779426574
# Avg loss over last 500 updates: 3.155802818775177
# Avg loss over last 500 updates: 3.2126001830101014
# Avg evaluation loss: 3.6013870629668236
# processed 11170 tokens with 1231 phrases; found: 913 phrases; correct: 624.
# accuracy:  58.54%; (non-O)
# accuracy:  92.56%; precision:  68.35%; recall:  50.69%; FB1:  58.21
#               LOC: precision:  78.99%; recall:  60.06%; FB1:  68.23  276
#              MISC: precision:  58.00%; recall:  30.21%; FB1:  39.73  100
#               ORG: precision:  53.27%; recall:  37.13%; FB1:  43.76  214
#               PER: precision:  72.45%; recall:  63.41%; FB1:  67.63  323
# (68.3461117196057, 50.69049553208773, 58.2089552238806)
# O precision 0.9368750631249368 recall 0.9916613213598461 f1 0.9634900025967281 count 9354
# I-PER precision 0.8886827458256029 recall 0.7507836990595611 f1 0.8139337298215804 count 638
# I-ORG precision 0.75 recall 0.48367346938775513 f1 0.5880893300248139 count 490
# I-LOC precision 0.8506493506493507 recall 0.6238095238095238 f1 0.7197802197802199 count 420
# I-MISC precision 0.8018867924528302 recall 0.3231939163498099 f1 0.4607046070460704 count 263
# B-MISC precision 0.0 recall 0.0 f1 0.0 count 1
# B-ORG precision 0.0 recall 0.0 f1 0.0 count 0
# B-LOC precision 0.0 recall 0.0 f1 0.0 count 4
# --- EPOCH 4 ---
# Avg loss over last 500 updates: 3.1042792897224425
# Avg loss over last 500 updates: 3.4282274549007417
# Avg loss over last 500 updates: 3.2033515915870665
# Avg loss over last 500 updates: 3.159292209625244
# Avg loss over last 500 updates: 3.1159478764534
# Avg loss over last 500 updates: 3.1254778308868407
# Avg evaluation loss: 3.3950684666633606
# processed 11170 tokens with 1231 phrases; found: 1017 phrases; correct: 669.
# accuracy:  62.22%; (non-O)
# accuracy:  92.51%; precision:  65.78%; recall:  54.35%; FB1:  59.52
#               LOC: precision:  78.62%; recall:  62.81%; FB1:  69.83  290
#              MISC: precision:  58.10%; recall:  31.77%; FB1:  41.08  105
#               ORG: precision:  53.70%; recall:  44.95%; FB1:  48.94  257
#               PER: precision:  66.30%; recall:  65.58%; FB1:  65.94  365
# (65.78171091445427, 54.346060113728676, 59.519572953736656)
# O precision 0.9440910956093558 recall 0.9838571734017533 f1 0.9635640247094545 count 9354
# I-PER precision 0.8235294117647058 recall 0.7899686520376176 f1 0.8064000000000001 count 638
# I-ORG precision 0.7165775401069518 recall 0.5469387755102041 f1 0.6203703703703703 count 490
# I-LOC precision 0.8359133126934984 recall 0.6428571428571429 f1 0.7267833109017496 count 420
# I-MISC precision 0.7787610619469026 recall 0.33460076045627374 f1 0.4680851063829786 count 263
# B-MISC precision 0.0 recall 0.0 f1 0.0 count 1
# B-ORG precision 0.0 recall 0.0 f1 0.0 count 0
# B-LOC precision 0.0 recall 0.0 f1 0.0 count 4
# --- EPOCH 5 ---
# Avg loss over last 500 updates: 2.936196994304657
# Avg loss over last 500 updates: 3.3403486037254333
# Avg loss over last 500 updates: 3.0371443448066713
# Avg loss over last 500 updates: 2.9586088590621946
# Avg loss over last 500 updates: 2.89244349861145
# Avg loss over last 500 updates: 3.131578824043274
# Avg evaluation loss: 3.6410367204248906
# processed 11170 tokens with 1231 phrases; found: 891 phrases; correct: 602.
# accuracy:  57.82%; (non-O)
# accuracy:  92.52%; precision:  67.56%; recall:  48.90%; FB1:  56.74
#               LOC: precision:  80.69%; recall:  57.58%; FB1:  67.20  259
#              MISC: precision:  59.80%; recall:  31.77%; FB1:  41.50  102
#               ORG: precision:  54.50%; recall:  39.41%; FB1:  45.75  222
#               PER: precision:  68.51%; recall:  57.18%; FB1:  62.33  308
# (67.5645342312009, 48.90333062550772, 56.73892554194156)
# O precision 0.9345747357825868 recall 0.9926234765875561 f1 0.9627248690963761 count 9354
# I-PER precision 0.9009708737864077 recall 0.7272727272727273 f1 0.8048568950563747 count 638
# I-ORG precision 0.7530864197530864 recall 0.49795918367346936 f1 0.5995085995085995 count 490
# I-LOC precision 0.8873239436619719 recall 0.6 f1 0.7159090909090908 count 420
# I-MISC precision 0.8035714285714286 recall 0.34220532319391633 f1 0.4799999999999999 count 263
# B-MISC precision 0.0 recall 0.0 f1 0.0 count 1
# B-ORG precision 0.0 recall 0.0 f1 0.0 count 0
# B-LOC precision 0.0 recall 0.0 f1 0.0 count 4
# --- EPOCH 6 ---
# Avg loss over last 500 updates: 2.967141126155853
# Avg loss over last 500 updates: 3.1349885787963867
# Avg loss over last 500 updates: 2.91045117855072
# Avg loss over last 500 updates: 2.9083252329826355
# Avg loss over last 500 updates: 2.9539825401306152
# Avg loss over last 500 updates: 2.9115801064968108
# Avg evaluation loss: 3.4814931759238243
# processed 11170 tokens with 1231 phrases; found: 922 phrases; correct: 631.
# accuracy:  59.03%; (non-O)
# accuracy:  92.65%; precision:  68.44%; recall:  51.26%; FB1:  58.62
#               LOC: precision:  82.37%; recall:  63.09%; FB1:  71.45  278
#              MISC: precision:  60.00%; recall:  31.25%; FB1:  41.10  100
#               ORG: precision:  54.59%; recall:  38.76%; FB1:  45.33  218
#               PER: precision:  68.40%; recall:  60.43%; FB1:  64.17  326
# (68.43817787418655, 51.2591389114541, 58.615884811890396)
# O precision 0.936976063023937 recall 0.9917682274962583 f1 0.9635938717216307 count 9354
# I-PER precision 0.8808193668528864 recall 0.7413793103448276 f1 0.8051063829787235 count 638
# I-ORG precision 0.7626582278481012 recall 0.49183673469387756 f1 0.598014888337469 count 490
# I-LOC precision 0.8831168831168831 recall 0.6476190476190476 f1 0.7472527472527473 count 420
# I-MISC precision 0.7962962962962963 recall 0.3269961977186312 f1 0.463611859838275 count 263
# B-MISC precision 0.0 recall 0.0 f1 0.0 count 1
# B-ORG precision 0.0 recall 0.0 f1 0.0 count 0
# B-LOC precision 0.0 recall 0.0 f1 0.0 count 4
# --- EPOCH 7 ---
# Avg loss over last 500 updates: 2.860610342741013
# Avg loss over last 500 updates: 3.0878650567531585
# Avg loss over last 500 updates: 2.708518539428711
# Avg loss over last 500 updates: 2.9256149203777313
# Avg loss over last 500 updates: 2.783224607229233
# Avg loss over last 500 updates: 2.9364232087135314
# Avg evaluation loss: 3.4040497614443304
# processed 11170 tokens with 1231 phrases; found: 964 phrases; correct: 653.
# accuracy:  61.18%; (non-O)
# accuracy:  92.86%; precision:  67.74%; recall:  53.05%; FB1:  59.50
#               LOC: precision:  81.68%; recall:  61.43%; FB1:  70.13  273
#              MISC: precision:  59.09%; recall:  33.85%; FB1:  43.05  110
#               ORG: precision:  52.16%; recall:  43.32%; FB1:  47.33  255
#               PER: precision:  71.17%; recall:  62.87%; FB1:  66.76  326
# (67.73858921161826, 53.046303818034126, 59.498861047835994)
# O precision 0.9419302349232177 recall 0.9901646354500748 f1 0.9654453536248502 count 9354
# I-PER precision 0.8915441176470589 recall 0.7601880877742947 f1 0.8206429780033841 count 638
# I-ORG precision 0.726775956284153 recall 0.5428571428571428 f1 0.6214953271028036 count 490
# I-LOC precision 0.8733766233766234 recall 0.6404761904761904 f1 0.7390109890109889 count 420
# I-MISC precision 0.7647058823529411 recall 0.34600760456273766 f1 0.4764397905759163 count 263
# B-MISC precision 0.0 recall 0.0 f1 0.0 count 1
# B-ORG precision 0.0 recall 0.0 f1 0.0 count 0
# B-LOC precision 0.0 recall 0.0 f1 0.0 count 4
# --- EPOCH 8 ---
# Avg loss over last 500 updates: 2.824498221874237
# Avg loss over last 500 updates: 3.021611612558365
# Avg loss over last 500 updates: 2.740884181499481
# Avg loss over last 500 updates: 2.7258705015182496
# Avg loss over last 500 updates: 2.7174514174461364
# Avg loss over last 500 updates: 2.868332607269287
# Avg evaluation loss: 3.3473507066071035
# processed 11170 tokens with 1231 phrases; found: 1025 phrases; correct: 703.
# accuracy:  64.70%; (non-O)
# accuracy:  93.27%; precision:  68.59%; recall:  57.11%; FB1:  62.32
#               LOC: precision:  80.97%; recall:  64.46%; FB1:  71.78  289
#              MISC: precision:  59.50%; recall:  37.50%; FB1:  46.01  121
#               ORG: precision:  54.34%; recall:  46.91%; FB1:  50.35  265
#               PER: precision:  72.29%; recall:  68.56%; FB1:  70.38  350
# (68.58536585365854, 57.10804224207961, 62.32269503546101)
# O precision 0.9484864032837352 recall 0.9881334188582425 f1 0.9679040787475784 count 9354
# I-PER precision 0.8646362098138748 recall 0.8009404388714734 f1 0.8315703824247356 count 638
# I-ORG precision 0.7400530503978779 recall 0.5693877551020409 f1 0.6435986159169551 count 490
# I-LOC precision 0.871875 recall 0.6642857142857143 f1 0.754054054054054 count 420
# I-MISC precision 0.7737226277372263 recall 0.40304182509505704 f1 0.53 count 263
# B-MISC precision 0.0 recall 0.0 f1 0.0 count 1
# B-ORG precision 0.0 recall 0.0 f1 0.0 count 0
# B-LOC precision 0.0 recall 0.0 f1 0.0 count 4
# --- EPOCH 9 ---
# Avg loss over last 500 updates: 2.6476445274353027
# Avg loss over last 500 updates: 2.943508170247078
# Avg loss over last 500 updates: 2.7700267231464384
# Avg loss over last 500 updates: 2.735057111740112
# Avg loss over last 500 updates: 2.5352001986503603
# Avg loss over last 500 updates: 2.7962917172908783
# Avg evaluation loss: 3.4885496751219036
# processed 11170 tokens with 1231 phrases; found: 983 phrases; correct: 663.
# accuracy:  61.40%; (non-O)
# accuracy:  92.70%; precision:  67.45%; recall:  53.86%; FB1:  59.89
#               LOC: precision:  78.11%; recall:  63.91%; FB1:  70.30  297
#              MISC: precision:  56.60%; recall:  31.25%; FB1:  40.27  106
#               ORG: precision:  54.05%; recall:  39.09%; FB1:  45.37  222
#               PER: precision:  70.11%; recall:  68.02%; FB1:  69.05  358
# (67.44659206510681, 53.858651502843216, 59.89159891598915)
# O precision 0.9420880913539967 recall 0.9878127004490058 f1 0.9644087256027554 count 9354
# I-PER precision 0.860738255033557 recall 0.8040752351097179 f1 0.8314424635332253 count 638
# I-ORG precision 0.74375 recall 0.4857142857142857 f1 0.5876543209876544 count 490
# I-LOC precision 0.8368580060422961 recall 0.6595238095238095 f1 0.7376830892143809 count 420
# I-MISC precision 0.7565217391304347 recall 0.33079847908745247 f1 0.4603174603174603 count 263
# B-MISC precision 0.0 recall 0.0 f1 0.0 count 1
# B-ORG precision 0.0 recall 0.0 f1 0.0 count 0
# B-LOC precision 0.0 recall 0.0 f1 0.0 count 4

# %%
evaluate(model, valid_data, word_vocab, label_vocab)
# Out:
# Avg evaluation loss: 3.4975596888363363
# processed 11170 tokens with 1231 phrases; found: 983 phrases; correct: 664.
# accuracy:  61.34%; (non-O)
# accuracy:  92.77%; precision:  67.55%; recall:  53.94%; FB1:  59.98
#               LOC: precision:  77.52%; recall:  63.64%; FB1:  69.89  298
#              MISC: precision:  56.19%; recall:  30.73%; FB1:  39.73  105
#               ORG: precision:  55.61%; recall:  40.39%; FB1:  46.79  223
#               PER: precision:  70.03%; recall:  67.75%; FB1:  68.87  357
# (67.54832146490337, 53.93988627132412, 59.98193315266486)
# O precision 0.9426154316583427 recall 0.9886679495403036 f1 0.9650926167492826 count 9354
# I-PER precision 0.8595600676818951 recall 0.7962382445141066 f1 0.8266883645240032 count 638
# I-ORG precision 0.75 recall 0.4959183673469388 f1 0.5970515970515972 count 490
# I-LOC precision 0.8368580060422961 recall 0.6595238095238095 f1 0.7376830892143809 count 420
# I-MISC precision 0.7610619469026548 recall 0.3269961977186312 f1 0.4574468085106383 count 263
# B-MISC precision 0.0 recall 0.0 f1 0.0 count 1
# B-ORG precision 0.0 recall 0.0 f1 0.0 count 0
# B-LOC precision 0.0 recall 0.0 f1 0.0 count 4
# ([['-DOCSTART-'],
#   ['Earlier',
#    'this',
#    'month',
#    ',',
#    '<unk>',
#    'denied',
#    'a',
#    'Kabul',
#    'government',
#    'statement',
#    'that',
#    'the',
#    'two',
#    'sides',
#    'had',
#    'agreed',
#    'to',
#    'a',
#    'ceasefire',
#    'in',
#    'the',
#    'north',
#    '.'],
#   ['0000', '<unk>', '<unk>', '0000', '0000', '0000', '0000'],
#   ['9.', '<unk>', '<unk>', '(', 'China', ')', '<unk>'],
#   ['<unk>', '0000', '0000', '0000', '0000', '0000', '0000', '0000'],
#   ['The',
#    'court',
#    '<unk>',
#    '<unk>',
#    "'s",
#    '<unk>',
#    'that',
#    '<unk>',
#    "'s",
#    '<unk>',
#    'from',
#    'Denmark',
#    ',',
#    'where',
#    'he',
#    'was',
#    'arrested',
#    'in',
#    'March',
#    'last',
#    'year',
#    'at',
#    'the',
#    'request',
#    'of',
#    'German',
#    'authorities',
#    ',',
#    'was',
#    'illegal',
#    '.'],
#   ['<unk>',
#    'Sudan',
#    'plane',
#    'expected',
#    'at',
#    'London',
#    "'s",
#    'Stansted',
#    '.'],
#   ['The',
#    'town',
#    "'s",
#    '<unk>',
#    '<unk>',
#    'ground',
#    'is',
#    '<unk>',
#    'only',
#    'by',
#    'two',
#    '<unk>',
#    '<unk>',
#    '.'],
#   ['<unk>', '<unk>', '<unk>', '<unk>'],
#   ['for', ',', 'against', ',', 'points', ')', ':'],
#   ['When', 'we', '<unk>', 'the', 'shares', 'we', '<unk>', '...'],
#   ['-DOCSTART-'],
#   ['Martinez',
#    '<unk>',
#    'play',
#    'against',
#    '<unk>',
#    '<unk>',
#    'of',
#    'Romania',
#    '.'],
#   ['<unk>', '<unk>', '0000', '0000', '0000', '0000', '0000', '0000', '0000'],
#   ['The',
#    '<unk>',
#    'said',
#    'the',
#    'problem',
#    'was',
#    '<unk>',
#    'during',
#    'the',
#    'past',
#    'month',
#    'during',
#    'which',
#    'time',
#    '<unk>',
#    '<unk>',
#    "'s",
#    'production',
#    'has',
#    '<unk>',
#    'from',
#    'maximum',
#    '<unk>',
#    'of',
#    '<unk>',
#    'bpd',
#    'to',
#    'as',
#    'low',
#    'as',
#    '<unk>',
#    'bpd',
#    ',',
#    '<unk>',
#    'on',
#    'the',
#    'crude',
#    'being',
#    'run',
#    '.'],
#   ['<unk>',
#    'to',
#    'the',
#    '<unk>',
#    "'s",
#    'weakness',
#    ',',
#    'another',
#    'dealer',
#    'said',
#    'banks',
#    'who',
#    'might',
#    'have',
#    'sold',
#    '<unk>',
#    'in',
#    'Monday',
#    "'s",
#    'trading',
#    'appeared',
#    'to',
#    '<unk>',
#    'away',
#    'from',
#    'the',
#    'market',
#    '.'],
#   ['There',
#    'was',
#    'no',
#    'independent',
#    'confirmation',
#    'of',
#    'the',
#    'report',
#    'which',
#    'the',
#    'spokesman',
#    'said',
#    'came',
#    'from',
#    'the',
#    'organisation',
#    "'s",
#    'members',
#    'in',
#    'Arbil',
#    '.'],
#   ['<unk>', '1996-08-29'],
#   ['Pires',
#    'scored',
#    'first',
#    'with',
#    'a',
#    '<unk>',
#    'shot',
#    'in',
#    'the',
#    '35th',
#    'minute',
#    'before',
#    '<unk>',
#    'again',
#    'from',
#    'close',
#    'range',
#    'just',
#    'before',
#    'the',
#    'break',
#    '.'],
#   ['<unk>',
#    '0000',
#    '(',
#    '<unk>',
#    '<unk>',
#    ',',
#    '<unk>',
#    '<unk>',
#    ',',
#    '<unk>',
#    '69th',
#    ')',
#    'Freiburg',
#    '0000',
#    '.'],
#   ['<unk>',
#    ',',
#    'whose',
#    'only',
#    'win',
#    'came',
#    'at',
#    'the',
#    '0000',
#    'Texas',
#    'Open',
#    'and',
#    'whose',
#    'best',
#    'finish',
#    'this',
#    'year',
#    'was',
#    'a',
#    '<unk>',
#    'tie',
#    'at',
#    'the',
#    '<unk>',
#    'Open',
#    'in',
#    'January',
#    ',',
#    '<unk>',
#    'the',
#    '<unk>',
#    'fourth',
#    '<unk>',
#    'and',
#    'added',
#    'five',
#    '<unk>',
#    'to',
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    'of',
#    'second',
#    'place',
#    '.'],
#   ['<unk>',
#    '<unk>',
#    '(',
#    'Czech',
#    'Republic',
#    ')',
#    'beat',
#    '<unk>',
#    '<unk>',
#    '(',
#    'Japan',
#    ')',
#    '6-',
#    '0000',
#    '3-6',
#    '7-5'],
#   ['<unk>', '<unk>', '<unk>', '5,000', 'Japan'],
#   ['<unk>', '<unk>', '0000', '0000', '0000', '0000', '0000', '0000', '0000'],
#   ['<unk>',
#    '<unk>',
#    '(',
#    'Belarus',
#    ')',
#    'beat',
#    '<unk>',
#    '<unk>',
#    '(',
#    'Spain',
#    ')',
#    '0000'],
#   ['<unk>',
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    '1-0',
#    'despite',
#    '<unk>',
#    'the',
#    'match',
#    'with',
#    'only',
#    'nine',
#    'men',
#    'following',
#    'the',
#    '<unk>',
#    'of',
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    'and',
#    '<unk>',
#    'van',
#    'der',
#    '<unk>',
#    '.'],
#   ['At',
#    'least',
#    '0000',
#    'miners',
#    'have',
#    'been',
#    'killed',
#    'in',
#    'labour',
#    '<unk>',
#    '--',
#    'sparked',
#    'by',
#    'ethnic',
#    '<unk>',
#    '--',
#    'at',
#    '<unk>',
#    '<unk>',
#    'and',
#    'Gold',
#    '<unk>',
#    "'",
#    '<unk>',
#    'Gold',
#    'Mining',
#    'Co',
#    'this',
#    'month',
#    '.'],
#   ['<unk>', '<unk>'],
#   ['-DOCSTART-'],
#   ['-DOCSTART-'],
#   ['<unk>', '0000'],
#   ['"', '<unk>', 'seen', '<unk>', '<unk>', 'his', 'goals', '...'],
#   ['One',
#    'of',
#    'the',
#    'great',
#    '<unk>',
#    'who',
#    '<unk>',
#    'over',
#    'a',
#    'period',
#    'of',
#    'English',
#    '<unk>',
#    'in',
#    'Europe',
#    'in',
#    'politics',
#    'and',
#    'the',
#    '<unk>',
#    '.'],
#   ['Sao', 'Paulo', '0000', 'Santos', '0000'],
#   ['-DOCSTART-'],
#   ['Results', 'of', '<unk>', 'in', 'the'],
#   ['<unk>', '0000', '0000', '0000', '0000', '0000', '0000', '0000'],
#   ['<unk>',
#    '<unk>',
#    'pitched',
#    'a',
#    '<unk>',
#    'ninth',
#    ',',
#    '<unk>',
#    'out',
#    'two',
#    '.'],
#   ['<unk>', 'Austria', '<unk>'],
#   ['<unk>',
#    'had',
#    'been',
#    'working',
#    'for',
#    'the',
#    '<unk>',
#    'which',
#    'provides',
#    'food',
#    'to',
#    'civilians',
#    'for',
#    'only',
#    'a',
#    'few',
#    'weeks',
#    'before',
#    'he',
#    'was',
#    '<unk>',
#    '.'],
#   ['<unk>',
#    '-',
#    '<unk>',
#    'Williams',
#    '0000',
#    ',',
#    '<unk>',
#    '<unk>',
#    '0000',
#    ',',
#    'Juan',
#    '<unk>',
#    '0000'],
#   ['Last',
#    'year',
#    ',',
#    'Martinez',
#    ',',
#    'who',
#    'finished',
#    '0000',
#    '<unk>',
#    'second',
#    'in',
#    'the',
#    'world',
#    ',',
#    'reached',
#    'the',
#    '<unk>',
#    'before',
#    '<unk>',
#    'out',
#    'to',
#    'Monica',
#    'Seles',
#    '.'],
#   ['May', '0000', 'v', 'Durham'],
#   ['<unk>', 'league', 'matches', 'on', 'Sunday', ':'],
#   ['Poland',
#    "'s",
#    'Foreign',
#    'Minister',
#    '<unk>',
#    'Rosati',
#    'will',
#    'visit',
#    'Yugoslavia',
#    'on',
#    'September',
#    '0000',
#    'and',
#    '0000',
#    'to',
#    'revive',
#    'a',
#    '<unk>',
#    'between',
#    'the',
#    'two',
#    'governments',
#    'which',
#    'was',
#    '<unk>',
#    '<unk>',
#    'in',
#    '0000',
#    ',',
#    '<unk>',
#    'news',
#    'agency',
#    'reported',
#    'on',
#    'Friday',
#    '.'],
#   ['Reuters',
#    'has',
#    'not',
#    'verified',
#    'these',
#    'stories',
#    'and',
#    'does',
#    'not',
#    'vouch',
#    'for',
#    'their',
#    'accuracy',
#    '.'],
#   ['NEW', 'YORK', '0000', '0000', '<unk>', '0000'],
#   ['Jim',
#    'Brady',
#    'then',
#    'gave',
#    'a',
#    'big',
#    '<unk>',
#    'to',
#    'the',
#    '<unk>',
#    '.'],
#   ['-DOCSTART-'],
#   ['India',
#    'fishermen',
#    'say',
#    'forced',
#    'to',
#    'carry',
#    'Tamil',
#    'refugees',
#    '.'],
#   ['Pakistan',
#    ',',
#    'who',
#    '<unk>',
#    'next',
#    'week',
#    ',',
#    'are',
#    'the',
#    'third',
#    'team',
#    'in',
#    'the',
#    '<unk>',
#    'World',
#    'Series',
#    'tournament',
#    '.'],
#   ['-',
#    'Pakistan',
#    '<unk>',
#    '<unk>',
#    'tonnes',
#    'of',
#    '<unk>',
#    '<unk>',
#    'yellow',
#    '<unk>',
#    'from',
#    '<unk>',
#    'Inc',
#    'for',
#    '$',
#    '<unk>',
#    'per',
#    'tonne',
#    ',',
#    '<unk>',
#    'U.S.',
#    'Gulf',
#    ',',
#    'agents',
#    'for',
#    'the',
#    '<unk>',
#    'said',
#    '.'],
#   ['<unk>',
#    'match',
#    'Blewett',
#    'came',
#    'to',
#    'the',
#    'wicket',
#    'with',
#    'the',
#    'total',
#    'on',
#    '0000',
#    'for',
#    'two',
#    'and',
#    'hit',
#    'three',
#    '<unk>',
#    'during',
#    'an',
#    '<unk>',
#    'innings',
#    '<unk>',
#    '0000',
#    'minutes',
#    '.'],
#   ['CRICKET',
#    '-',
#    'ENGLAND',
#    '<unk>',
#    '<unk>',
#    'FOR',
#    'ONE-DAY',
#    '<unk>',
#    '.'],
#   ['He',
#    'walked',
#    'three',
#    'and',
#    'struck',
#    'out',
#    'three',
#    'in',
#    'winning',
#    'for',
#    'the',
#    '10th',
#    'time',
#    'in',
#    'his',
#    'last',
#    '0000',
#    '<unk>',
#    '.'],
#   ['-DOCSTART-'],
#   ['Extras', '(', '<unk>', '<unk>', '<unk>', '<unk>', ')', '0000'],
#   ['<unk>',
#    'to',
#    'the',
#    '<unk>',
#    'sector',
#    'fell',
#    '<unk>',
#    'percent',
#    'to',
#    '<unk>',
#    'tonnes',
#    ',',
#    'while',
#    'the',
#    '<unk>',
#    'sector',
#    'rose',
#    '<unk>',
#    'percent',
#    'to',
#    '<unk>',
#    'tonnes',
#    '.'],
#   ['Canada',
#    "'s",
#    '<unk>',
#    '<unk>',
#    'finished',
#    'second',
#    'in',
#    'his',
#    'Williams'],
#   ['FOR', '<unk>', '<unk>', '<unk>', '<unk>'],
#   ['-DOCSTART-'],
#   ['<unk>', '1996-08-26'],
#   ['<unk>', '0000', '0000', '0000', '0000', '0000', '0000', '0000'],
#   ['AUG', '0000', '<unk>', "'S", '<unk>', '0000', '<unk>', '0000', '<unk>'],
#   ['LONDON', '1996-08-28'],
#   ['<unk>',
#    '<unk>',
#    ',',
#    'deposed',
#    'leader',
#    'of',
#    'the',
#    'Indonesian',
#    'Democratic',
#    'Party',
#    '(',
#    '<unk>',
#    ')',
#    'has',
#    '<unk>',
#    'the',
#    'government',
#    'for',
#    '<unk>',
#    'her',
#    'as',
#    '<unk>',
#    'leader',
#    '.'],
#   ['Russian',
#    'and',
#    'rebel',
#    'military',
#    '<unk>',
#    'finally',
#    'met',
#    'in',
#    'Chechnya',
#    'on',
#    'Tuesday',
#    'for',
#    'delayed',
#    'talks',
#    'aimed',
#    'at',
#    '<unk>',
#    'a',
#    'ceasefire',
#    '<unk>',
#    'last',
#    'week',
#    'by',
#    'President',
#    '<unk>',
#    'Yeltsin',
#    "'s",
#    '<unk>',
#    'Alexander',
#    'Lebed',
#    '.'],
#   ['<unk>',
#    'of',
#    'the',
#    'fire',
#    'has',
#    'been',
#    '<unk>',
#    'because',
#    'of',
#    'the',
#    'hot',
#    ',',
#    '<unk>',
#    ',',
#    '<unk>',
#    'weather',
#    'in',
#    'the',
#    'region',
#    ',',
#    '<unk>',
#    'said',
#    '.'],
#   ['-DOCSTART-'],
#   ['Attendance', ':', '<unk>'],
#   ['MILWAUKEE', 'AT', 'CHICAGO'],
#   ['NAC', 'Breda', '0000', 'Sparta', 'Rotterdam', '0000'],
#   ['<unk>', 'Moody', 'not', 'out', '0000'],
#   ['2.', '<unk>', '<unk>', '(', 'Finland', ')', '<unk>', '<unk>', '<unk>'],
#   ['Ricky',
#    '<unk>',
#    'led',
#    'the',
#    'way',
#    'with',
#    '0000',
#    'off',
#    '0000',
#    'balls',
#    'with',
#    'two',
#    '<unk>',
#    'and',
#    'nine',
#    '<unk>',
#    'before',
#    'retiring',
#    '.'],
#   ['U.S.',
#    'debt',
#    'futures',
#    'end',
#    'lower',
#    ',',
#    '<unk>',
#    'by',
#    'Chicago',
#    '<unk>',
#    '.'],
#   ['<unk>', '0000', '0000', '0000', '0000', '0000', '0000', '0000'],
#   ['Suu',
#    'Kyi',
#    ',',
#    'who',
#    '<unk>',
#    'a',
#    'campaign',
#    'for',
#    'sanctions',
#    'on',
#    '<unk>',
#    "'s",
#    'government',
#    ',',
#    'was',
#    'under',
#    'house',
#    'arrest',
#    'for',
#    'six',
#    'years',
#    'without',
#    'being',
#    'tried',
#    'before',
#    'being',
#    'released',
#    'in',
#    'July',
#    '0000',
#    '.'],
#   ['--',
#    'Amsterdam',
#    'newsroom',
#    '<unk>',
#    '0000',
#    '0000',
#    '0000',
#    ',',
#    '<unk>',
#    '<unk>',
#    '0000',
#    '0000',
#    '0000'],
#   ['<unk>', '<unk>', 'AT', 'NEW', 'YORK'],
#   ['Reading', '0000', '0000', '0000', '0000', '0000', '0000', '0000'],
#   ['<unk>',
#    'from',
#    'the',
#    '<unk>',
#    'at',
#    '0000',
#    'to',
#    '0000',
#    '<unk>',
#    '(',
#    '0000',
#    'to',
#    '0000',
#    '<unk>',
#    '/',
#    '0000',
#    'to',
#    '0000',
#    'miles',
#    'per',
#    'hour',
#    ')',
#    '.'],
#   ['From',
#    'central',
#    'Texas',
#    'north',
#    'to',
#    'Kansas',
#    ',',
#    '<unk>',
#    'throughout',
#    'July',
#    'and',
#    'August',
#    'have',
#    '<unk>',
#    'most',
#    'of',
#    'the',
#    '<unk>',
#    'conditions',
#    'that',
#    '<unk>',
#    'the',
#    'region',
#    'earlier',
#    'this',
#    'year',
#    '.'],
#   ['-DOCSTART-'],
#   ['SOCCER', '-', '<unk>', 'FIRST', 'DIVISION', 'SUMMARY', '.'],
#   ['At', 'Leicester', ':', '<unk>', 'drawn', '.'],
#   ['<unk>', 'Bremen', '0000', '<unk>', '<unk>', '0000'],
#   ['SOCCER',
#    '-',
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    'MANCHESTER',
#    '<unk>',
#    '.'],
#   ['<unk>',
#    'president',
#    '<unk>',
#    'Meri',
#    'won',
#    '0000',
#    'votes',
#    'compared',
#    'to',
#    '0000',
#    'won',
#    'by',
#    'his',
#    'rival',
#    ',',
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    'Ruutel',
#    '.'],
#   ['4.', 'El', '<unk>', '<unk>', '(', 'Morocco', ')', '<unk>'],
#   ['<unk>', '0000', '0000', '0000', '0000', '0000', '0000', '0000'],
#   ['<unk>',
#    'fellow',
#    'Indian',
#    '<unk>',
#    '<unk>',
#    'Mauritius',
#    '1-0',
#    'from',
#    'the',
#    'first',
#    'leg',
#    ',',
#    'they',
#    'were',
#    'held',
#    'to',
#    'a',
#    '1-1',
#    'draw',
#    'at',
#    'home',
#    'on',
#    'Saturday',
#    'despite',
#    'playing',
#    'against',
#    '0000',
#    'men',
#    'for',
#    'most',
#    'of',
#    'the',
#    'match',
#    '.'],
#   ['Philippoussis',
#    '<unk>',
#    'a',
#    'match',
#    'point',
#    'at',
#    '<unk>',
#    'in',
#    'the',
#    '<unk>',
#    'tie',
#    'break',
#    'before',
#    'winning',
#    '6-3',
#    '3-6',
#    '7-6',
#    '(',
#    '8-6',
#    ')',
#    '.'],
#   ['<unk>',
#    'only',
#    'hours',
#    'after',
#    'Chinese',
#    'state',
#    'media',
#    'said',
#    'the',
#    'time',
#    'was',
#    'right',
#    'to',
#    '<unk>',
#    'in',
#    'political',
#    'talks',
#    'with',
#    'Taiwan',
#    ',',
#    'Foreign',
#    'Ministry',
#    'spokesman',
#    '<unk>',
#    '<unk>',
#    'told',
#    'Reuters',
#    ':',
#    '"',
#    'The',
#    '<unk>',
#    '<unk>',
#    'for',
#    'the',
#    'opening',
#    'of',
#    'the',
#    'talks',
#    'has',
#    'been',
#    '<unk>',
#    'by',
#    'the',
#    'Taiwan',
#    'authorities',
#    '.',
#    '"'],
#   ['14.', '<unk>', '0000', '0000', '-', '0000', '0000', '0000', '0000'],
#   ['SOCCER',
#    '-',
#    '<unk>',
#    "'S",
#    '<unk>',
#    '<unk>',
#    "'",
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    'FOR',
#    '<unk>',
#    '.'],
#   ['<unk>', '1996-12-07'],
#   ['The',
#    'Greek',
#    '<unk>',
#    'party',
#    "'s",
#    'executive',
#    'bureau',
#    'gave',
#    'the',
#    '<unk>',
#    'light',
#    'to',
#    'Prime',
#    'Minister',
#    '<unk>',
#    '<unk>',
#    'to',
#    'call',
#    '<unk>',
#    'elections',
#    ',',
#    'its',
#    'general',
#    'secretary',
#    '<unk>',
#    '<unk>',
#    'told',
#    'reporters',
#    '.'],
#   ['It', 'was', 'the', 'second', 'arms', '<unk>', 'this', 'week', '.'],
#   ['<unk>',
#    '<unk>',
#    '<unk>',
#    '-',
#    '<unk>',
#    'C',
#    '0000',
#    'OF',
#    '<unk>',
#    '0000',
#    ',',
#    '0000',
#    '.'],
#   ['Brooks',
#    '0000',
#    '0000',
#    '0000',
#    '0000',
#    ',',
#    'Nick',
#    'Faldo',
#    '(',
#    'Britain',
#    ')',
#    '0000',
#    '0000',
#    '0000',
#    '0000'],
#   ['Peter', '<unk>'],
#   ['A',
#    'human',
#    'rights',
#    '<unk>',
#    'said',
#    'on',
#    'Wednesday',
#    'he',
#    'had',
#    'been',
#    'released',
#    'after',
#    'more',
#    'than',
#    'two',
#    'weeks',
#    'in',
#    '<unk>',
#    'that',
#    'followed',
#    'his',
#    'call',
#    'for',
#    'an',
#    '<unk>',
#    'into',
#    'the',
#    'death',
#    'of',
#    'a',
#    'Gaza',
#    'man',
#    '<unk>',
#    'by',
#    'Palestinian',
#    'police',
#    '.'],
#   ['<unk>', '<unk>'],
#   ['As',
#    'an',
#    '<unk>',
#    ',',
#    'Albright',
#    '<unk>',
#    'and',
#    '<unk>',
#    'on',
#    'Europe',
#    "'s",
#    '<unk>',
#    'century',
#    'problems',
#    'before',
#    '<unk>',
#    'U.S.',
#    'ambassador',
#    'to',
#    'the',
#    'United',
#    'Nations',
#    '.'],
#   ['"',
#    '<unk>',
#    'is',
#    'getting',
#    'stronger',
#    'and',
#    'stronger',
#    ',',
#    'and',
#    'it',
#    'already',
#    'has',
#    '<unk>',
#    'of',
#    '0000',
#    '<unk>',
#    '(',
#    '0000',
#    'kph',
#    ')',
#    ',',
#    '"',
#    'said',
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    '.'],
#   ['He',
#    'is',
#    'not',
#    'as',
#    '<unk>',
#    'as',
#    'he',
#    'used',
#    'to',
#    'be',
#    'be',
#    'but',
#    'was',
#    'too',
#    'good',
#    'for',
#    'me',
#    'in',
#    'the',
#    'end',
#    '.'],
#   ['South',
#    'Africa',
#    '-',
#    '0000',
#    '-',
#    'Andre',
#    'Joubert',
#    ',',
#    '0000',
#    '-',
#    'Justin',
#    '<unk>',
#    ',',
#    '0000',
#    '-',
#    '<unk>',
#    '<unk>',
#    '(',
#    '<unk>',
#    '<unk>',
#    ',',
#    '0000',
#    '<unk>',
#    ')',
#    '0000',
#    '-',
#    '<unk>',
#    'van',
#    '<unk>',
#    ',',
#    '0000',
#    '-',
#    '<unk>',
#    '<unk>',
#    ';',
#    '0000',
#    '-',
#    'Henry',
#    '<unk>',
#    ',',
#    '0000',
#    '-',
#    '<unk>',
#    'van',
#    'der',
#    '<unk>',
#    ';',
#    '0000',
#    '-',
#    'Gary',
#    '<unk>',
#    '(',
#    'captain',
#    ')',
#    ',',
#    '0000',
#    '-',
#    'Andre',
#    '<unk>',
#    '(',
#    '<unk>',
#    '<unk>',
#    ',',
#    '0000',
#    ')',
#    ',',
#    '0000',
#    '-',
#    '<unk>',
#    '<unk>',
#    ',',
#    '0000',
#    '-',
#    'Mark',
#    '<unk>',
#    '(',
#    '<unk>',
#    'van',
#    '<unk>',
#    ',',
#    '0000',
#    ')',
#    ',',
#    '0000',
#    '-',
#    '<unk>',
#    '<unk>',
#    ',',
#    '0000',
#    '-',
#    '<unk>',
#    '<unk>',
#    ',',
#    '0000',
#    '-',
#    'James',
#    '<unk>',
#    ',',
#    '0000',
#    '-',
#    '<unk>',
#    '<unk>',
#    '(',
#    '<unk>',
#    '<unk>',
#    ',',
#    '0000',
#    ')',
#    '.'],
#   ['<unk>',
#    'said',
#    'books',
#    'by',
#    'other',
#    '<unk>',
#    ',',
#    'including',
#    'British',
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    ',',
#    'were',
#    'also',
#    '<unk>',
#    '.'],
#   ['<unk>',
#    'police',
#    'shot',
#    'dead',
#    'six',
#    '<unk>',
#    'suspects',
#    'as',
#    'they',
#    'tried',
#    'to',
#    'escape',
#    'from',
#    '<unk>',
#    'in',
#    'the',
#    'northern',
#    'city',
#    'of',
#    '<unk>',
#    ',',
#    'the',
#    'national',
#    'news',
#    'agency',
#    'reported',
#    'on',
#    'Friday',
#    '.'],
#   ['<unk>', '1996-08-24'],
#   ['<unk>',
#    'were',
#    '<unk>',
#    'in',
#    'the',
#    'money',
#    'market',
#    'but',
#    '<unk>',
#    'in',
#    'bonds',
#    '.'],
#   ['<unk>',
#    "'s",
#    'own',
#    'export',
#    'performance',
#    'was',
#    '<unk>',
#    'better',
#    'than',
#    'in',
#    '<unk>',
#    'on',
#    'account',
#    'of',
#    'a',
#    '0000',
#    'percent',
#    'rise',
#    'in',
#    'exports',
#    'to',
#    'Nepal',
#    'and',
#    'the',
#    'opening',
#    'of',
#    'a',
#    'new',
#    'market',
#    '-',
#    'Sri',
#    'Lanka',
#    ',',
#    'he',
#    'said',
#    '.'],
#   ['9.', '<unk>', '0000'],
#   ['<unk>', '1996-12-06'],
#   ['TENNIS',
#    '-',
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    '-',
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    'AT',
#    'U.S.',
#    'OPEN',
#    '.'],
#   ['The',
#    'man',
#    ',',
#    'doing',
#    'his',
#    'rounds',
#    'in',
#    'the',
#    'northern',
#    'city',
#    'of',
#    '<unk>',
#    'on',
#    'the',
#    'day',
#    'when',
#    'German',
#    'children',
#    '<unk>',
#    '<unk>',
#    'small',
#    '<unk>',
#    'from',
#    '<unk>',
#    '<unk>',
#    ',',
#    'convinced',
#    'police',
#    'eventually',
#    'that',
#    'he',
#    'was',
#    '<unk>',
#    '.'],
#   ['All',
#    '<unk>',
#    "'s",
#    'Association',
#    'secretary',
#    'N.J.',
#    '<unk>',
#    'said',
#    'the',
#    'strike',
#    'would',
#    'continue',
#    '<unk>',
#    'and',
#    'the',
#    'fishermen',
#    'would',
#    'block',
#    'road',
#    'and',
#    'rail',
#    'traffic',
#    'if',
#    'their',
#    '<unk>',
#    'were',
#    'not',
#    'met',
#    '.'],
#   ['<unk>',
#    'organisers',
#    'said',
#    'the',
#    '<unk>',
#    '<unk>',
#    'remained',
#    '<unk>',
#    'but',
#    'it',
#    'would',
#    'probably',
#    'take',
#    'about',
#    'a',
#    'month',
#    'to',
#    '<unk>',
#    'an',
#    '<unk>',
#    'college',
#    'which',
#    'could',
#    'also',
#    'hold',
#    'several',
#    'rounds',
#    'of',
#    '<unk>',
#    'before',
#    'a',
#    'clear',
#    'winner',
#    '<unk>',
#    '.'],
#   ['ATHLETICS',
#    '-',
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    'WORLD',
#    'RECORD',
#    'IN',
#    '0000',
#    '<unk>',
#    '.'],
#   ['<unk>', '<unk>', 'snapped', 'by', 'cool', 'passenger', '.'],
#   ['Bank',
#    'of',
#    'New',
#    'Zealand',
#    'said',
#    'on',
#    'Thursday',
#    'it',
#    'was',
#    '<unk>',
#    'its',
#    '<unk>',
#    'home',
#    'lending',
#    'rates',
#    '.'],
#   ['Qualifier', 'vs.', 'qualifier'],
#   ['<unk>',
#    ',',
#    '0000',
#    ',',
#    'had',
#    'complained',
#    'of',
#    'lower',
#    'back',
#    '<unk>',
#    'since',
#    'a',
#    'trip',
#    'to',
#    'Taiwan',
#    'in',
#    'May',
#    ',',
#    'when',
#    '<unk>',
#    'forced',
#    'her',
#    'to',
#    'go',
#    'to',
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    'for',
#    'an',
#    '<unk>',
#    '.'],
#   ['<unk>', '<unk>', '0000', '<unk>', 'Moscow', '0000'],
#   ['--', 'Wellington', 'newsroom', '0000', '0000', '0000', '0000'],
#   ['-DOCSTART-'],
#   ['<unk>', ',', 'West', 'Bank', '1996-08-28'],
#   ['-DOCSTART-'],
#   ['-DOCSTART-'],
#   ['1.',
#    '<unk>',
#    '<unk>',
#    '(',
#    'Italy',
#    ')',
#    '<unk>',
#    '(',
#    'world',
#    'record',
#    ')'],
#   ['PARIS', '1996-08-24'],
#   ['<unk>',
#    'was',
#    'a',
#    'key',
#    'player',
#    'in',
#    'President',
#    'Bill',
#    'Clinton',
#    "'s",
#    'failed',
#    'attempt',
#    'at',
#    'sweeping',
#    '<unk>',
#    'changes',
#    'but',
#    'when',
#    'he',
#    '<unk>',
#    '<unk>',
#    'leader',
#    'he',
#    'declared',
#    'he',
#    'would',
#    'be',
#    'no',
#    '<unk>',
#    'for',
#    'the',
#    'White',
#    'House',
#    '.'],
#   ['W', 'D', 'L', 'G', '/', 'F', 'G', '/', 'A', '<unk>'],
#   ['The',
#    'ministers',
#    'agreed',
#    'at',
#    'Tuesday',
#    "'s",
#    'cabinet',
#    'meeting',
#    'to',
#    'step',
#    'up',
#    '<unk>',
#    'measures',
#    'for',
#    'school',
#    '<unk>',
#    'in',
#    'September',
#    'and',
#    'October',
#    ',',
#    'when',
#    '<unk>',
#    'around',
#    'the',
#    'country',
#    'resume',
#    '.'],
#   ['The',
#    'victory',
#    'against',
#    'Japan',
#    '<unk>',
#    'the',
#    'Fed',
#    'Cup',
#    'debut',
#    'of',
#    'Monica',
#    'Seles',
#    ',',
#    'who',
#    '<unk>',
#    'a',
#    '<unk>',
#    'U.S.',
#    'citizen',
#    'in',
#    '0000',
#    '.'],
#   ['-DOCSTART-'],
#   ['A',
#    'note',
#    'with',
#    'the',
#    '<unk>',
#    'demand',
#    'was',
#    'left',
#    'in',
#    'the',
#    'couple',
#    "'s",
#    'car',
#    ',',
#    'which',
#    'was',
#    'used',
#    'in',
#    'the',
#    'kidnapping',
#    ',',
#    '<unk>',
#    'told',
#    'a',
#    'news',
#    'conference',
#    'on',
#    'Monday',
#    '.'],
#   ['5.', 'Steve', 'Brown', '(', 'U.S.', ')', '<unk>'],
#   ['The',
#    '<unk>',
#    'said',
#    '<unk>',
#    '<unk>',
#    'had',
#    'also',
#    'been',
#    'used',
#    'to',
#    'film',
#    'the',
#    'couple',
#    'and',
#    'that',
#    'a',
#    '<unk>',
#    '<unk>',
#    '.'],
#   ['Iran',
#    "'s",
#    '<unk>',
#    'representative',
#    'to',
#    'the',
#    'United',
#    'Nations',
#    ',',
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    ',',
#    'made',
#    'the',
#    '<unk>',
#    'in',
#    'a',
#    'letter',
#    'to',
#    'U.N.',
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    'on',
#    'Friday',
#    ',',
#    'the',
#    'agency',
#    'said',
#    '.'],
#   ['<unk>', '1996-08-26'],
#   ['Extras', '(', 'nb-8', ')', '0000'],
#   ['-', '<unk>', '0000', 'down', '<unk>'],
#   ['In',
#    'one',
#    'letter',
#    ',',
#    'a',
#    'black',
#    '<unk>',
#    '<unk>',
#    'South',
#    '<unk>',
#    'his',
#    'wife',
#    ',',
#    '"',
#    '<unk>',
#    'great',
#    'is',
#    'the',
#    '<unk>',
#    'national',
#    '<unk>',
#    'yet',
#    'I',
#    'look',
#    'forward',
#    'to',
#    'a',
#    '<unk>',
#    'day',
#    'when',
#    'I',
#    '<unk>',
#    'have',
#    'the',
#    '<unk>',
#    'of',
#    'seeing',
#    'you',
#    'in',
#    'the',
#    'full',
#    '<unk>',
#    'of',
#    'freedom',
#    '.'],
#   ['-DOCSTART-'],
#   ['<unk>',
#    '<unk>',
#    '<unk>',
#    'remain',
#    '<unk>',
#    'for',
#    'the',
#    '<unk>',
#    'of',
#    '<unk>',
#    'in',
#    'the',
#    'region',
#    '.'],
#   ['Some',
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    'they',
#    'can',
#    'actually',
#    '<unk>',
#    'to',
#    'such',
#    'a',
#    'point',
#    'that',
#    'they',
#    'fly',
#    '.'],
#   ['Rudar', '0000', '0000', '0000', '0000', '0000', '0000', '0000'],
#   ['<unk>', '0000', '0000', '0000', '0000', '0000', '0000'],
#   ['The',
#    '<unk>',
#    'Woods',
#    ',',
#    'who',
#    'turned',
#    '<unk>',
#    'Tuesday',
#    'after',
#    'winning',
#    'an',
#    '<unk>',
#    'third',
#    'successive',
#    'U.S.',
#    '<unk>',
#    '<unk>',
#    ',',
#    '<unk>',
#    'on',
#    'the',
#    'front',
#    'nine',
#    ',',
#    '<unk>',
#    'the',
#    'first',
#    'and',
#    'seventh',
#    '<unk>',
#    'and',
#    '<unk>',
#    'the',
#    '<unk>',
#    ',',
#    '<unk>',
#    'ninth',
#    '<unk>',
#    '.'],
#   ['The',
#    '<unk>',
#    'will',
#    'visit',
#    '<unk>',
#    'before',
#    '<unk>',
#    'in',
#    'the',
#    'Chinese',
#    'capital',
#    ',',
#    'Beijing',
#    ',',
#    'early',
#    'next',
#    'week',
#    ',',
#    'officials',
#    'said',
#    '.'],
#   ['<unk>', 'Moscow', '(', 'Russia', ')', '0000', '0000', '0000', '0000'],
#   ['<unk>',
#    'newspapers',
#    'said',
#    'the',
#    'men',
#    'had',
#    'been',
#    '<unk>',
#    'against',
#    '"',
#    'strategic',
#    '<unk>',
#    'and',
#    '<unk>',
#    '<unk>',
#    '"',
#    'but',
#    'gave',
#    'no',
#    'other',
#    'details',
#    '.'],
#   ['On',
#    'Tuesday',
#    'night',
#    ',',
#    'Kevorkian',
#    '<unk>',
#    'the',
#    'death',
#    'of',
#    '<unk>',
#    '<unk>',
#    ',',
#    'a',
#    '<unk>',
#    'Texas',
#    'woman',
#    'with',
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    ',',
#    'or',
#    '<unk>',
#    '<unk>',
#    "'s",
#    'disease',
#    '.'],
#   ['<unk>',
#    'Abu',
#    '<unk>',
#    ',',
#    'said',
#    '<unk>',
#    'Ministry',
#    '<unk>',
#    'had',
#    'told',
#    'him',
#    'to',
#    '<unk>',
#    'all',
#    'the',
#    '<unk>',
#    'of',
#    'the',
#    'August',
#    '<unk>',
#    'back',
#    'to',
#    'Cyprus',
#    'at',
#    'his',
#    'own',
#    '<unk>',
#    '.'],
#   ['But',
#    'spending',
#    'on',
#    '<unk>',
#    'products',
#    'increased',
#    '<unk>',
#    'to',
#    'a',
#    'rate',
#    'of',
#    '$',
#    '<unk>',
#    'trillion',
#    'from',
#    '$',
#    '<unk>',
#    'trillion',
#    'in',
#    'June',
#    ',',
#    'while',
#    'spending',
#    'for',
#    'services',
#    'was',
#    'up',
#    'to',
#    '$',
#    '<unk>',
#    'trillion',
#    'in',
#    'July',
#    'from',
#    '$',
#    '<unk>',
#    'trillion',
#    '.'],
#   ['8.', 'Michael', '<unk>', '(', 'Germany', ')', '<unk>'],
#   ['<unk>', 'win', '2-1', 'on', 'aggregate', '.'],
#   ['Barbara',
#    '<unk>',
#    '(',
#    'Germany',
#    ')',
#    'beat',
#    '0000',
#    '-',
#    '<unk>',
#    '<unk>',
#    '('],
#   ['<unk>', 'Real', 'Madrid', '<unk>'],
#   ['More', '<unk>', 'results', 'are', 'expected', 'soon', '.'],
#   ['0000', '-', '<unk>', '<unk>'],
#   ['0000',
#    '-',
#    'British',
#    '<unk>',
#    'Alan',
#    'John',
#    '<unk>',
#    '(',
#    '<unk>',
#    ')',
#    'Taylor',
#    'died',
#    '.'],
#   ['15.', '<unk>', '<unk>', '(', 'South', 'Africa', ')', '<unk>'],
#   ['0000',
#    '-',
#    '<unk>',
#    '<unk>',
#    '(',
#    'South',
#    'Africa',
#    ')',
#    'beat',
#    'Todd',
#    '<unk>'],
#   ['<unk>',
#    '<unk>',
#    '0000',
#    '-',
#    '<unk>',
#    '0000',
#    ':',
#    '<unk>',
#    'of',
#    '<unk>',
#    'at',
#    '$',
#    '<unk>',
#    ',',
#    '10,000',
#    'of',
#    '<unk>',
#    'at',
#    '$',
#    '<unk>',
#    ',',
#    '<unk>',
#    'of',
#    '<unk>',
#    'at',
#    '$',
#    '<unk>',
#    '.'],
#   ['"',
#    'Three',
#    'of',
#    'the',
#    'four',
#    'children',
#    'had',
#    '<unk>',
#    "'s",
#    'disease',
#    ',',
#    '"',
#    '<unk>',
#    "'s",
#    'group',
#    '<unk>',
#    'in',
#    'the',
#    '<unk>',
#    'medical',
#    '<unk>',
#    '.'],
#   ['<unk>',
#    '<unk>',
#    'of',
#    'Finland',
#    ',',
#    'driving',
#    'a',
#    '<unk>',
#    ',',
#    'on',
#    'Monday',
#    'won',
#    'the',
#    '1,000',
#    'Lakes',
#    'Rally',
#    ',',
#    'sixth',
#    'round',
#    'of',
#    'the',
#    'world',
#    'championship',
#    '.'],
#   ['Company', '<unk>', '<unk>', '<unk>', 'Inc'],
#   ['<unk>', '<unk>', '0000', '0000', 'loss', '0000', '0000', 'profit'],
#   ['<unk>',
#    'San',
#    'Diego',
#    'has',
#    'won',
#    'seven',
#    'of',
#    'its',
#    'last',
#    'eight',
#    'games',
#    'and',
#    'improved',
#    'to',
#    '<unk>',
#    'against',
#    '<unk>',
#    'East',
#    '<unk>',
#    '.'],
#   ['Results', 'of', 'South', 'Korean'],
#   ['-DOCSTART-'],
#   ['--', 'Bangkok', 'newsroom', '<unk>'],
#   ['(', '<unk>', ')', '7-6', '(', '7-4', ')'],
#   ['<unk>',
#    '<unk>',
#    '(',
#    'Romania',
#    ')',
#    'beat',
#    '<unk>',
#    '<unk>',
#    '(',
#    'Germany',
#    ')',
#    '6-3',
#    '6-2'],
#   ['LOS', 'ANGELES', '<unk>'],
#   ['As', 'often', ',', 'the', 'most', 'volume', 'was', 'in', '<unk>', '.'],
#   ['<unk>', '<unk>', '0000', '<unk>', '<unk>', '0000'],
#   ['<unk>', '-', '<unk>', '<unk>', '(', '<unk>', ')', ',', '<unk>', '<unk>'],
#   ['-', '<unk>', '<unk>', 'up', '<unk>'],
#   ['Local',
#    'officials',
#    'said',
#    'one',
#    'policeman',
#    'was',
#    'killed',
#    'by',
#    '<unk>',
#    'during',
#    'clashes',
#    'with',
#    '<unk>',
#    'students',
#    'on',
#    'Thursday',
#    '.'],
#   ['Zimbabwe', 'on', 'Monday', ':'],
#   ['Aberdeen', 'v', 'Hearts'],
#   ['-DOCSTART-'],
#   ['Indian',
#    'officials',
#    'blame',
#    '<unk>',
#    'Moslem',
#    '<unk>',
#    '<unk>',
#    'in',
#    '<unk>',
#    'for',
#    'a',
#    'string',
#    'of',
#    '<unk>',
#    'in',
#    'the',
#    'city',
#    'three',
#    'months',
#    'later',
#    'that',
#    'killed',
#    '0000',
#    'people',
#    '.'],
#   ['The',
#    'PKK',
#    'also',
#    '<unk>',
#    'into',
#    'Turkey',
#    'from',
#    '<unk>',
#    'in',
#    'the',
#    '<unk>',
#    'of',
#    'northern',
#    'Iraq',
#    '.'],
#   ['SOCCER', '-', '<unk>', 'FIRST', 'DIVISION', 'RESULTS', '.'],
#   ['The',
#    '<unk>',
#    'American',
#    '<unk>',
#    'off',
#    'the',
#    'Stadium',
#    'Court',
#    'for',
#    '<unk>',
#    'of',
#    'an',
#    'upset',
#    'stomach',
#    'after',
#    'his',
#    'two',
#    'and',
#    'a',
#    'half',
#    'hour',
#    'struggle',
#    'against',
#    '<unk>',
#    '.'],
#   ['Nigeria',
#    'is',
#    'under',
#    'fire',
#    'from',
#    'many',
#    'Western',
#    'countries',
#    'for',
#    'human',
#    'rights',
#    '<unk>',
#    'and',
#    'lack',
#    'of',
#    'democracy',
#    '.'],
#   ['The',
#    'popular',
#    '<unk>',
#    'is',
#    'playing',
#    'his',
#    'final',
#    'major',
#    'tournament',
#    'next',
#    'week',
#    'and',
#    'the',
#    '<unk>',
#    'champion',
#    "'s",
#    'Grand',
#    'Slam',
#    '<unk>',
#    'could',
#    'well',
#    'be',
#    'a',
#    '<unk>',
#    '<unk>',
#    '.'],
#   ['<unk>', '<unk>', '<unk>', '(', 'Netherlands', ')', '<unk>', '<unk>'],
#   ['-DOCSTART-'],
#   ['<unk>', '<unk>', '<unk>'],
#   ['Middlesbrough', '0000', '0000', '0000', '0000', '0000', '0000', '0000'],
#   ['<unk>',
#    'David',
#    '<unk>',
#    ',',
#    'who',
#    '<unk>',
#    '<unk>',
#    ',',
#    'told',
#    'the',
#    'Sun',
#    ':',
#    '"',
#    'There',
#    'is',
#    'a',
#    'risk',
#    'he',
#    'could',
#    'be',
#    '<unk>',
#    'in',
#    'the',
#    'eye',
#    'if',
#    'he',
#    'steps',
#    'into',
#    'the',
#    'ring',
#    'again',
#    '.'],
#   ['<unk>',
#    '-',
#    '<unk>',
#    '<unk>',
#    'figures',
#    '<unk>',
#    'to',
#    'value',
#    'of',
#    'orders',
#    'on',
#    'books',
#    'at',
#    'end',
#    'of',
#    'period',
#    '.'],
#   ['Hong',
#    'Kong',
#    "'s",
#    'Tsang',
#    'sees',
#    'growth',
#    ',',
#    '<unk>',
#    '<unk>',
#    '.'],
#   ['BASEBALL', '-', 'RESULTS', 'OF', 'S.', '<unk>', '<unk>', 'GAMES', '.'],
#   ['8.', '<unk>', '<unk>', '(', 'Kenya', ')', '<unk>'],
#   ['England'],
#   ['<unk>', 'United', '0000', '<unk>', '0000'],
#   ['9.',
#    'Britain',
#    'I',
#    '(',
#    '<unk>',
#    '<unk>',
#    ',',
#    '<unk>',
#    '<unk>',
#    ')',
#    '<unk>',
#    '(',
#    '<unk>'],
#   ['ATLANTA', 'AT', 'NEW', '<unk>'],
#   ['German',
#    '<unk>',
#    '<unk>',
#    'of',
#    'motor',
#    '<unk>',
#    'jumped',
#    '<unk>',
#    'percent',
#    'in',
#    'July',
#    'this',
#    'year',
#    'from',
#    'the',
#    '<unk>',
#    'period',
#    ',',
#    'the',
#    'Federal',
#    'office',
#    'for',
#    'motor',
#    '<unk>',
#    'said',
#    'on',
#    'Thursday',
#    '.'],
#   ['<unk>', '0000', '0000', '0000', '0000', '0000', '0000', '0000'],
#   ['Peru',
#    "'s",
#    'guerrillas',
#    '<unk>',
#    'one',
#    ',',
#    'take',
#    '0000',
#    '<unk>',
#    'in',
#    '<unk>',
#    '.'],
#   ['<unk>', '-', '<unk>', '<unk>', '<unk>', '<unk>', '(', '<unk>', ')'],
#   ['MANCHESTER', ',', 'England', '1996-08-30'],
#   ['2.', '<unk>', 'Sang', '(', 'Kenya', ')', '<unk>'],
#   ['June',
#    '<unk>',
#    'v',
#    'British',
#    '<unk>',
#    '(',
#    'at',
#    'Oxford',
#    ',',
#    'three',
#    'days',
#    ')'],
#   ['"',
#    'I',
#    'will',
#    'be',
#    'happy',
#    'to',
#    'give',
#    'him',
#    'the',
#    'award',
#    '<unk>',
#    'on',
#    'January',
#    '0000',
#    'in',
#    '<unk>',
#    'and',
#    'I',
#    "'m",
#    '<unk>',
#    'that',
#    'Costa',
#    'himself',
#    'will',
#    'be',
#    'there',
#    '<unk>',
#    'me',
#    'on',
#    'that',
#    'day',
#    'to',
#    '<unk>',
#    'his',
#    'hand',
#    '.',
#    '"'],
#   ['Steve',
#    '<unk>',
#    ',',
#    'who',
#    'tied',
#    'for',
#    'second',
#    'at',
#    'last',
#    'week',
#    "'s",
#    'World',
#    'Series',
#    'of',
#    'Golf',
#    ',',
#    'and',
#    '<unk>',
#    '<unk>',
#    'were',
#    'both',
#    'five',
#    'shots',
#    'off',
#    'the',
#    'lead',
#    'at',
#    '0000',
#    'under',
#    '.'],
#   ['<unk>', '<unk>'],
#   ['<unk>', '<unk>'],
#   ['In',
#    'the',
#    'central',
#    'bank',
#    "'s",
#    'latest',
#    'bid',
#    'to',
#    '<unk>',
#    'Taiwan',
#    "'s",
#    '<unk>',
#    'economy',
#    ',',
#    '<unk>',
#    'ordered',
#    'a',
#    '<unk>',
#    'of',
#    'up',
#    'to',
#    'a',
#    '<unk>',
#    'point',
#    'in',
#    'banks',
#    "'",
#    '<unk>',
#    '<unk>',
#    'and',
#    'called',
#    'on',
#    'commercial',
#    'banks',
#    'to',
#    '<unk>',
#    'on',
#    'the',
#    '<unk>',
#    'in',
#    'the',
#    'form',
#    'of',
#    'interest',
#    'rate',
#    '<unk>',
#    '.'],
#   ['One',
#    'officer',
#    'and',
#    'a',
#    '<unk>',
#    'killed',
#    'in',
#    '<unk>',
#    'clash',
#    'between',
#    'two',
#    'groups',
#    'of',
#    'soldiers',
#    'near',
#    '<unk>',
#    'in',
#    '<unk>',
#    '.'],
#   ['14.', 'Alexandra', '<unk>', '(', '<unk>'],
#   ['<unk>',
#    '<unk>',
#    '<unk>',
#    'said',
#    'on',
#    'Thursday',
#    'it',
#    'will',
#    '<unk>',
#    'its',
#    'cash',
#    '<unk>',
#    'rate',
#    'for',
#    'the',
#    'October',
#    '<unk>',
#    '<unk>',
#    ',',
#    '<unk>',
#    'continued',
#    '<unk>',
#    'results',
#    '.'],
#   ['.'],
#   ['Argentine',
#    'July',
#    '<unk>',
#    '<unk>',
#    'output',
#    'up',
#    '<unk>',
#    'pct',
#    'vs',
#    "'",
#    '0000',
#    '.'],
#   ['<unk>', 'Mushtaq', 'b', 'Harris', '0000'],
#   ['<unk>',
#    ',',
#    'with',
#    'a',
#    '<unk>',
#    'of',
#    '<unk>',
#    ',',
#    'has',
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    ',',
#    'with',
#    '<unk>',
#    'new',
#    'cars',
#    'having',
#    'been',
#    '<unk>',
#    'on',
#    'the',
#    '<unk>',
#    '<unk>',
#    'in',
#    '0000',
#    'years',
#    '.'],
#   ['Brazil',
#    '-',
#    'Giovanni',
#    '(',
#    '<unk>',
#    ')',
#    ',',
#    '<unk>',
#    '<unk>',
#    '(',
#    '<unk>',
#    ')'],
#   ['"',
#    'We',
#    '<unk>',
#    'to',
#    'start',
#    'international',
#    'telephone',
#    'business',
#    'as',
#    'soon',
#    'as',
#    'possible',
#    ',',
#    '"',
#    'a',
#    'company',
#    'official',
#    'told',
#    'Reuters',
#    '.'],
#   ['<unk>',
#    '<unk>',
#    '(',
#    'Japan',
#    ')',
#    'beat',
#    '<unk>',
#    '<unk>',
#    '(',
#    'Yugoslavia',
#    ')',
#    '6-3',
#    '6-2'],
#   ['Attendance', '<unk>', '.'],
#   ['The',
#    'Brazilian',
#    "'s",
#    '<unk>',
#    'effort',
#    'was',
#    'enough',
#    'to',
#    '<unk>',
#    'Real',
#    'a',
#    'point',
#    'from',
#    'a',
#    '<unk>',
#    '1-1',
#    'draw',
#    'at',
#    'fellow',
#    'title',
#    'contenders',
#    '<unk>',
#    '<unk>',
#    '.'],
#   ['-DOCSTART-'],
#   ['SEATTLE', '0000', '0000', '<unk>', '0000'],
#   ['He',
#    'spent',
#    'a',
#    'year',
#    'under',
#    'house',
#    'arrest',
#    'and',
#    'was',
#    'tried',
#    'but',
#    '<unk>',
#    'last',
#    'year',
#    'on',
#    'charges',
#    'of',
#    'ordering',
#    'the',
#    'murder',
#    'of',
#    'four',
#    '<unk>',
#    'in',
#    '0000',
#    '.'],
#   ['The',
#    'Office',
#    'of',
#    '<unk>',
#    'Trade',
#    'called',
#    'for',
#    'British',
#    'Airways',
#    '/',
#    'American',
#    'to',
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    'to',
#    'their',
#    'joint',
#    'frequent',
#    '<unk>',
#    'programme',
#    'where',
#    'the',
#    '<unk>',
#    'does',
#    'not',
#    'have',
#    '<unk>',
#    'to',
#    'an',
#    'equivalent',
#    'programme',
#    '.'],
#   ['<unk>',
#    'Rubin',
#    'leave',
#    ',',
#    'Wall',
#    'Street',
#    'would',
#    'worry',
#    'that',
#    'he',
#    'might',
#    'take',
#    'his',
#    '<unk>',
#    'policy',
#    'with',
#    'him',
#    '.'],
#   ['"',
#    'I',
#    'think',
#    'the',
#    '<unk>',
#    '<unk>',
#    'Association',
#    'should',
#    'look',
#    'into',
#    'this',
#    '<unk>',
#    'and',
#    'deal',
#    'with',
#    'it',
#    '<unk>',
#    '.'],
#   ['A',
#    'lower',
#    'court',
#    'issued',
#    'the',
#    '<unk>',
#    'on',
#    'Friday',
#    'and',
#    'ordered',
#    'Lloyd',
#    "'s",
#    'to',
#    'give',
#    'investors',
#    ',',
#    'known',
#    'as',
#    '<unk>',
#    ',',
#    'more',
#    'information',
#    'before',
#    '<unk>',
#    'them',
#    'to',
#    '<unk>',
#    'whether',
#    'to',
#    'accept',
#    'a',
#    'settlement',
#    'offer',
#    'as',
#    'part',
#    'of',
#    'a',
#    '<unk>',
#    'plan',
#    '.'],
#   ['<unk>', '<unk>', '0000', '0000', '0000', '0000', '0000', '0000', '0000'],
#   ['<unk>', 'kills', '0000', 'at', '<unk>', '<unk>', '<unk>', '.'],
#   ['But',
#    'he',
#    '<unk>',
#    'that',
#    'policy',
#    'would',
#    'be',
#    '<unk>',
#    'by',
#    'Clinton',
#    'and',
#    'President',
#    '<unk>',
#    'Yeltsin',
#    '.'],
#   ['SOCCER', '-', '<unk>', '<unk>', '<unk>', '<unk>', '.'],
#   ['"',
#    'There',
#    'was',
#    'no',
#    '<unk>',
#    'today',
#    'to',
#    'make',
#    'a',
#    '<unk>',
#    'run',
#    ',',
#    '"',
#    'said',
#    '<unk>',
#    '<unk>',
#    ',',
#    'the',
#    'Canadian',
#    'men',
#    "'s",
#    'national',
#    'coach',
#    ',',
#    '<unk>',
#    'too',
#    'much',
#    'new',
#    '<unk>',
#    'and',
#    'poor',
#    '<unk>',
#    '.'],
#   ['<unk>', '0000', '<unk>', '0000'],
#   ['SOCCER', '-', '<unk>', 'LEAGUE', 'STANDINGS', '.'],
#   ['<unk>', ':'],
#   ['<unk>',
#    'said',
#    'he',
#    'knew',
#    'of',
#    'no',
#    'plans',
#    'to',
#    'return',
#    'the',
#    'man',
#    'to',
#    'Cuba',
#    '.'],
#   ['<unk>', ',', '<unk>', '1996-08-30'],
#   ['TENNIS',
#    '-',
#    '<unk>',
#    ',',
#    'U.S.',
#    '<unk>',
#    'OPEN',
#    '<unk>',
#    '<unk>',
#    'FOR',
#    '0000',
#    '<unk>',
#    'CUP',
#    '.'],
#   ['<unk>',
#    'parties',
#    ',',
#    '<unk>',
#    'organisations',
#    'and',
#    '<unk>',
#    'unions',
#    'have',
#    'expressed',
#    'support',
#    'for',
#    'the',
#    'action',
#    'and',
#    '<unk>',
#    'the',
#    'government',
#    "'s",
#    'pay',
#    'rises',
#    'of',
#    'up',
#    'to',
#    'eight',
#    'percent',
#    'for',
#    'its',
#    'workers',
#    '.'],
#   ['<unk>', '<unk>', '0000', '<unk>', '<unk>', '0000'],
#   ['<unk>', '0000', '0000', '0000', '<unk>', '0000'],
#   ['Police',
#    'who',
#    'had',
#    'turned',
#    'out',
#    'in',
#    'force',
#    'all',
#    'around',
#    'the',
#    'government',
#    'quarter',
#    '<unk>',
#    'violence',
#    'looked',
#    'on',
#    'in',
#    '<unk>',
#    '.'],
#   ['<unk>', '<unk>', 'c', '<unk>', 'b', 'Wasim', 'Akram', '0000'],
#   ['Hapoel', '<unk>', '0000', 'Maccabi', 'Tel', 'Aviv', '0000'],
#   ['Tottenham', '0000', '0000', '0000', '0000', '0000', '0000', '0000'],
#   ['The',
#    'committee',
#    'said',
#    'the',
#    'Italian',
#    'club',
#    'had',
#    '<unk>',
#    '<unk>',
#    'by',
#    '<unk>',
#    'to',
#    '<unk>',
#    'Feyenoord',
#    ',',
#    'with',
#    'whom',
#    'the',
#    'player',
#    'was',
#    'under',
#    'contract',
#    '.'],
#   ['-DOCSTART-'],
#   ['The',
#    '<unk>',
#    'were',
#    'held',
#    'in',
#    'a',
#    'house',
#    'in',
#    'or',
#    'near',
#    'Grozny',
#    'which',
#    'was',
#    '<unk>',
#    '<unk>',
#    '.'],
#   ['<unk>', '1996-08-25'],
#   ['<unk>', '<unk>'],
#   ['<unk>',
#    'that',
#    'information',
#    'about',
#    '<unk>',
#    'was',
#    '"',
#    'as',
#    '<unk>',
#    'as',
#    'the',
#    '<unk>',
#    'he',
#    '<unk>',
#    '"',
#    ',',
#    'Jordan',
#    'said',
#    'he',
#    'made',
#    'some',
#    '<unk>',
#    '<unk>',
#    'in',
#    'the',
#    'film',
#    '.'],
#   ['<unk>',
#    'health',
#    'began',
#    'to',
#    '<unk>',
#    'in',
#    '0000',
#    'when',
#    'she',
#    'was',
#    '<unk>',
#    'with',
#    'a',
#    'heart',
#    '<unk>',
#    '.'],
#   ['Indonesia', '0000', '0000', '0000', '0000', '0000', '0000', '0000'],
#   ['<unk>',
#    'government',
#    'newspapers',
#    'have',
#    '<unk>',
#    'Britain',
#    'for',
#    'allowing',
#    'Islamists',
#    ',',
#    'whom',
#    'they',
#    '<unk>',
#    'as',
#    '"',
#    '<unk>',
#    '"',
#    ',',
#    'to',
#    'hold',
#    'their',
#    'conference',
#    ',',
#    'saying',
#    'the',
#    'meeting',
#    'will',
#    'be',
#    'a',
#    'chance',
#    'for',
#    'dangerous',
#    'Moslem',
#    '<unk>',
#    'to',
#    '<unk>',
#    'against',
#    'their',
#    'countries',
#    'of',
#    '<unk>',
#    '.'],
#   ['-DOCSTART-'],
#   ['0000',
#    '-',
#    '<unk>',
#    'Sanchez',
#    '<unk>',
#    '(',
#    'Spain',
#    ')',
#    'beat',
#    '<unk>',
#    '<unk>'],
#   ['WASHINGTON', '1996-08-29'],
#   ['-DOCSTART-'],
#   ['<unk>',
#    'them',
#    ',',
#    'he',
#    '<unk>',
#    'that',
#    'Cofinec',
#    'had',
#    '<unk>',
#    'the',
#    'outstanding',
#    'stake',
#    'in',
#    'its',
#    'Czech',
#    '<unk>',
#    'company',
#    '<unk>',
#    '<unk>',
#    ',',
#    'increasing',
#    'its',
#    '<unk>',
#    'to',
#    '0000',
#    'percent',
#    ',',
#    'so',
#    'in',
#    'the',
#    'second',
#    'half',
#    'the',
#    'whole',
#    'of',
#    '<unk>',
#    "'s",
#    'figures',
#    'will',
#    'be',
#    '<unk>',
#    '.'],
#   ['Cincinnati', '0000', 'ATLANTA', '0000', '(', 'in', '0000', ')'],
#   ['Pakistani', 'bourse', 'to', 'use', 'new', '<unk>', 'index', '.'],
#   ['Martin', '<unk>', ',', '<unk>', '<unk>', '(', 'Sweden', ')'],
#   ['He',
#    '<unk>',
#    'for',
#    'a',
#    '<unk>',
#    'and',
#    'a',
#    '<unk>',
#    'opening',
#    'round',
#    'that',
#    'left',
#    'him',
#    'five',
#    'shots',
#    'off',
#    'the',
#    '<unk>',
#    '.'],
#   ['The',
#    '<unk>',
#    'in',
#    'dog',
#    '<unk>',
#    'by',
#    '<unk>',
#    '<unk>',
#    'have',
#    'more',
#    'to',
#    'do',
#    'with',
#    '<unk>',
#    '<unk>',
#    'owned',
#    'by',
#    '<unk>',
#    'who',
#    'need',
#    'to',
#    'have',
#    'something',
#    '<unk>',
#    '.'],
#   ['for', ',', 'against', ',', 'points', ')', ':'],
#   ['"',
#    'My',
#    '<unk>',
#    'this',
#    'year',
#    'has',
#    'been',
#    '<unk>',
#    ',',
#    '"',
#    '<unk>',
#    'said',
#    '.',
#    '"'],
#   ['"',
#    'I',
#    'think',
#    'we',
#    'would',
#    'have',
#    '<unk>',
#    'to',
#    'have',
#    'more',
#    'of',
#    '<unk>',
#    'but',
#    'it',
#    "'s",
#    'the',
#    'question',
#    'of',
#    'adding',
#    'value',
#    '.'],
#   ['David',
#    '<unk>',
#    '(',
#    'Czech',
#    'Republic',
#    ')',
#    'beat',
#    '<unk>',
#    '<unk>',
#    '(',
#    'Morocco',
#    ')',
#    '6-4',
#    '7-5',
#    '6-2'],
#   ['<unk>', ',', 'England', '1996-08-27'],
#   ['<unk>', '<unk>'],
#   ['Current',
#    'air',
#    '<unk>',
#    'were',
#    'designed',
#    'to',
#    'halt',
#    'the',
#    'forward',
#    '<unk>',
#    'of',
#    'an',
#    '<unk>',
#    ',',
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    ',',
#    'not',
#    'a',
#    'small',
#    'child',
#    '.'],
#   ['With',
#    'their',
#    'fifth',
#    'straight',
#    'win',
#    ',',
#    'the',
#    'Dodgers',
#    'moved',
#    'a',
#    '<unk>',
#    'ahead',
#    'of',
#    'the',
#    '<unk>',
#    'at',
#    'the',
#    'top',
#    'of',
#    'the',
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    'behind',
#    '<unk>',
#    '(',
#    '<unk>',
#    ')',
#    ',',
#    'who',
#    'allowed',
#    'six',
#    'hits',
#    'and',
#    'walked',
#    'four',
#    'with',
#    'six',
#    '<unk>',
#    '.'],
#   ['The', 'teams', 'meet', 'each', 'other', 'once', 'in', 'each'],
#   ['Port', 'Vale', '0000', '0000', '0000', '0000', '0000', '0000', '0000'],
#   ['"', 'We', '<unk>', 'Iraqi', '<unk>', '.'],
#   ['0000',
#    '-',
#    '<unk>',
#    '<unk>',
#    '(',
#    'Chile',
#    ')',
#    'beat',
#    '<unk>',
#    '<unk>',
#    '(',
#    'Australia',
#    ')',
#    '<unk>'],
#   ['It',
#    'said',
#    'Craig',
#    '<unk>',
#    'has',
#    'also',
#    'joined',
#    'the',
#    'company',
#    'as',
#    'executive',
#    '<unk>',
#    'president',
#    'and',
#    'chief',
#    '<unk>',
#    'officer',
#    '.'],
#   ['ATLANTA', '0000', '0000', '<unk>', '-'],
#   ['England',
#    '<unk>',
#    'their',
#    'championship',
#    '<unk>',
#    'when',
#    'they',
#    'decided',
#    'to',
#    'sign',
#    'a',
#    '<unk>',
#    'million',
#    'pounds',
#    'sterling',
#    '(',
#    '$',
#    '<unk>',
#    'million',
#    ')',
#    'deal',
#    'giving',
#    '<unk>',
#    'television',
#    '<unk>',
#    'rights',
#    'to',
#    '<unk>',
#    'union',
#    'matches',
#    'in',
#    'England',
#    '.'],
#   ['The',
#    'September',
#    'bond',
#    'future',
#    'on',
#    'LIFFE',
#    'was',
#    'trading',
#    'at',
#    '<unk>',
#    ',',
#    'down',
#    '<unk>',
#    'from',
#    'Thursday',
#    "'s",
#    'settlement',
#    'price',
#    '.'],
#   ['<unk>', '0000', '0000', '0000', '0000', '0000', '0000', '0000'],
#   ['5.', '<unk>', '<unk>'],
#   ['<unk>', 'Moscow', '0000', '<unk>', '<unk>', '<unk>', '0000'],
#   ['<unk>', 'times', 'set', 'on', 'Friday'],
#   ['Austrian',
#    'television',
#    'reported',
#    'earlier',
#    'that',
#    'more',
#    'than',
#    '0000',
#    'had',
#    'been',
#    'hurt',
#    'in',
#    'the',
#    'accident',
#    'at',
#    'the',
#    '<unk>',
#    'in',
#    '<unk>',
#    ',',
#    '0000',
#    'km',
#    '(',
#    '0000',
#    'miles',
#    ')',
#    'west',
#    'of',
#    'Vienna',
#    '.'],
#   ['Cash', '<unk>', '/', '<unk>', '<unk>', '<unk>'],
#   ['Our',
#    '<unk>',
#    'is',
#    '<unk>',
#    ',',
#    '<unk>',
#    'and',
#    'respect',
#    ',',
#    '"',
#    'she',
#    'said',
#    '.'],
#   ['Romania', 'state', 'budget', '<unk>', 'in', 'June', '.'],
#   ['Leading', '<unk>', 'in'],
#   ['<unk>', '<unk>', '<unk>', 'tonnes', 'changed', 'from', 'unknown', '.'],
#   ['Leeds', 'v', 'Wimbledon'],
#   ['Czech',
#    'President',
#    '<unk>',
#    'Havel',
#    'on',
#    'Friday',
#    'welcomed',
#    'the',
#    '<unk>',
#    'of',
#    '<unk>',
#    'Albright',
#    ',',
#    'who',
#    'is',
#    'of',
#    'Czech',
#    '<unk>',
#    ',',
#    'as',
#    'the',
#    'United',
#    'States',
#    "'",
#    'first',
#    'woman',
#    'Secretary',
#    'of',
#    'State',
#    '.'],
#   ['NEW', 'YORK', '1996-12-07'],
#   ['<unk>',
#    '0000',
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    '/',
#    '<unk>',
#    '<unk>',
#    '<unk>',
#    '.'],
#   ['Waqar', 'Younis', '<unk>', '<unk>', 'b', 'Harris', '0000'],
#   ['In',
#    'another',
#    'attack',
#    ',',
#    'also',
#    'on',
#    'the',
#    'province',
#    "'s",
#    'south',
#    'coast',
#    'on',
#    'Thursday',
#    'night',
#    ',',
#    'two',
#    'men',
#    'were',
#    'shot',
#    'dead',
#    'near',
#    '<unk>',
#    '.'],
#   ['3.', 'Sven', '<unk>', '(', 'Germany', ')', 'U.S.', '<unk>'],
#   ['"',
#    'He',
#    "'s",
#    'a',
#    '<unk>',
#    'and',
#    'a',
#    '<unk>',
#    ',',
#    'but',
#    'he',
#    '<unk>',
#    'the',
#    '<unk>',
#    'between',
#    'a',
#    '<unk>',
#    '<unk>',
#    'and',
#    'an',
#    '<unk>',
#    '.'],
#   ['-DOCSTART-'],
#   ['<unk>', 'TO', '<unk>'],
#   ['To',
#    'replace',
#    '<unk>',
#    ',',
#    'the',
#    '<unk>',
#    'after',
#    'the',
#    'trial',
#    'named',
#    '<unk>',
#    'as',
#    '"',
#    '<unk>',
#    '"',
#    'but',
#    '<unk>',
#    '<unk>',
#    ',',
#    'the',
#    'last',
#    'of',
#    'the',
#    '<unk>',
#    '<unk>',
#    'members',
#    'still',
#    '<unk>',
#    'active',
#    ',',
#    'claimed',
#    'the',
#    'title',
#    'of',
#    'president',
#    ',',
#    '<unk>',
#    'a',
#    'new',
#    'split',
#    'within',
#    'the',
#    'movement',
#    '.'],
#   ['Jordan',
#    ',',
#    'whose',
#    '0000',
#    'film',
#    '"',
#    'The',
#    '<unk>',
#    '<unk>',
#    '"',
#    'also',
#    'came',
#    'under',
#    'fire',
#    'for',
#    'what',
#    'was',
#    '<unk>',
#    'as',
#    'a',
#    '<unk>',
#    '<unk>',
#    'of',
#    'the',
#    '<unk>',
#    ',',
#    'said',
#    '<unk>',
#    'was',
#    'more',
#    'than',
#    'just',
#    'a',
#    '<unk>',
#    '.'],
#   ['-DOCSTART-'],
#   ['But',
#    'the',
#    '<unk>',
#    'towns',
#    'got',
#    'off',
#    '<unk>',
#    'as',
#    'the',
#    '<unk>',
#    'that',
#    'had',
#    'been',
#    'expected',
#    'due',
#    'to',
#    'a',
#    '<unk>',
#    'of',
#    '<unk>',
#    '<unk>',
#    'and',
#    'high',
#    '<unk>',
#    'failed',
#    'to',
#    '<unk>',
#    '.'],
#   ['Last',
#    'month',
#    ',',
#    'Wang',
#    ',',
#    '0000',
#    ',',
#    'a',
#    'veteran',
#    '<unk>',
#    'of',
#    'the',
#    '0000',
#    'Democracy',
#    'Wall',
#    'movement',
#    ',',
#    'was',
#    'ordered',
#    'to',
#    'serve',
#    'one',
#    'year',
#    'of',
#    '"',
#    '<unk>',
#    'through',
#    'labour',
#    '"',
#    ',',
#    'but',
#    'released',
#    'because',
#    'of',
#    'poor',
#    'health',
#    '.'],
#   ['Halftime', '1-0', '.'],
#   ['Bowling', ':'],
#   ['He',
#    'had',
# ...
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-PER',
#    'I-PER',
#    'O',
#    'I-ORG',
#    'I-ORG',
#    'O',
#    'O',
#    'I-LOC',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'I-MISC', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['I-LOC', 'O'],
#   ['O'],
#   ['I-ORG', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'I-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-ORG',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'I-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'I-PER', 'O', 'O', 'I-PER', 'O', 'O', 'O'],
#   ['I-PER',
#    'O',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-LOC',
#    'O',
#    'I-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['I-LOC', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O', 'O'],
#   ['I-ORG', 'O', 'O', 'O', 'O'],
#   ['O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-PER',
#    'I-PER',
#    'O',
#    'I-LOC',
#    'O',
#    'O',
#    'I-PER',
#    'I-PER',
#    'O',
#    'I-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-PER',
#    'I-PER',
#    'O',
#    'I-LOC',
#    'O',
#    'O',
#    'I-PER',
#    'I-PER',
#    'O',
#    'I-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O'],
#   ['O',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['I-ORG', 'O', 'O', 'O', 'O'],
#   ['O',
#    'I-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-PER',
#    'O',
#    'I-ORG',
#    'O'],
#   ['O', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O'],
#   ['O',
#    'I-LOC',
#    'I-ORG',
#    'O',
#    'I-PER',
#    'I-PER',
#    'O',
#    'I-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-ORG',
#    'I-ORG',
#    'I-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-ORG',
#    'I-ORG',
#    'O'],
#   ['I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'I-PER',
#    'I-PER',
#    'O',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'I-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'I-PER',
#    'I-ORG',
#    'O',
#    'O',
#    'I-PER',
#    'O',
#    'O',
#    'I-PER',
#    'O',
#    'O'],
#   ['O', 'I-PER', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-LOC',
#    'I-ORG',
#    'I-ORG',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-ORG',
#    'I-ORG',
#    'I-ORG',
#    'I-ORG',
#    'I-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'I-PER', 'I-PER', 'O', 'O'],
#   ['I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['I-ORG', 'O', 'O'],
#   ['I-LOC', 'O', 'I-LOC', 'O'],
#   ['O', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'O', 'I-LOC', 'I-LOC', 'O'],
#   ['O',
#    'I-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-LOC',
#    'I-LOC',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'I-LOC', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O'],
#   ['O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'I-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-PER',
#    'I-PER',
#    'O',
#    'O',
#    'I-LOC',
#    'O',
#    'O'],
#   ['O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'I-LOC', 'O', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['I-ORG', 'I-ORG', 'O', 'O', 'O', 'O'],
#   ['O',
#    'I-PER',
#    'I-PER',
#    'I-PER',
#    'O',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-LOC',
#    'I-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'I-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'I-PER',
#    'I-PER',
#    'O',
#    'I-LOC',
#    'O',
#    'O',
#    'I-PER',
#    'I-PER',
#    'O',
#    'I-LOC',
#    'O'],
#   ['I-LOC', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['I-LOC', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['I-LOC', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'I-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-LOC',
#    'I-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-ORG',
#    'I-ORG',
#    'O',
#    'O',
#    'O',
#    'I-ORG',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O'],
#   ['I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O'],
#   ['O'],
#   ['O', 'O', 'I-ORG', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-LOC',
#    'O',
#    'O',
#    'O',
#    'I-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-LOC',
#    'I-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-LOC',
#    'I-LOC',
#    'O',
#    'O'],
#   ['O',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'I-MISC', 'O', 'O', 'O'],
#   ['I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-MISC',
#    'O',
#    'I-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['I-LOC', 'O', 'I-LOC', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['I-LOC', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'I-PER',
#    'I-PER',
#    'O',
#    'I-LOC',
#    'O',
#    'O',
#    'I-PER',
#    'I-PER',
#    'O',
#    'I-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O'],
#   ['I-ORG'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-MISC',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'I-PER',
#    'O',
#    'I-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'I-PER', 'I-PER', 'O', 'I-LOC', 'O', 'O'],
#   ['O', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'I-LOC', 'O'],
#   ['I-ORG', 'O', 'O', 'O', 'O'],
#   ['I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ['I-MISC',
#    'O',
#    'I-LOC',
#    'I-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-LOC',
#    'O',
#    'I-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['I-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-ORG',
#    'I-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['I-ORG', 'O', 'O'],
#   ['O'],
#   ['O', 'I-PER', 'I-PER', 'O', 'O', 'O', 'I-PER', 'I-PER', 'O', 'O'],
#   ['O', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'I-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-LOC',
#    'O',
#    'I-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-LOC',
#    'I-LOC',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O'],
#   ['O',
#    'O',
#    'I-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['I-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-PER'],
#   ['O', 'O', 'O'],
#   ['I-ORG', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'I-MISC',
#    'O',
#    'I-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'I-PER',
#    'I-PER',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'I-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']])
